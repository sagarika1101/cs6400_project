# %%
import pymongo
import csv
import json

# %%
myclient = pymongo.MongoClient("mongodb://localhost:27017/")

# %%
mydb = myclient["cs6400"]

# %%
print(myclient.list_database_names())
# Out:
# ['admin', 'config', 'cs6400', 'local']

# %%
print(mydb.list_collection_names())
# Out:
# ['result', 'complete']

# %%
mycol = mydb['complete']

# %%
# Query1: Find number of all crimes in each borough
result = mycol.aggregate([
    # Group the documents and "count" via $sum on the values
    { "$group": {
        "_id": {
            "Borough": "$BORO_NM",
            "Crime_Type" : "$LAW_CAT_CD"
        },
        "#Crimes": { "$sum": 1 }
    }}
])
for x in result:
    print(x)
# Out:
# {'_id': {'Borough': 'QUEENS', 'Crime_Type': 'MISDEMEANOR'}, '#Crimes': 11817}
# {'_id': {'Borough': 'MANHATTAN', 'Crime_Type': 'FELONY'}, '#Crimes': 8735}
# {'_id': {'Borough': 'MANHATTAN', 'Crime_Type': 'VIOLATION'}, '#Crimes': 4489}
# {'_id': {'Borough': 'BROOKLYN', 'Crime_Type': 'FELONY'}, '#Crimes': 10549}
# {'_id': {'Borough': 'QUEENS', 'Crime_Type': 'FELONY'}, '#Crimes': 7593}
# {'_id': {'Borough': 'STATEN ISLAND', 'Crime_Type': 'MISDEMEANOR'}, '#Crimes': 2161}
# {'_id': {'Borough': 'BRONX', 'Crime_Type': 'VIOLATION'}, '#Crimes': 5236}
# {'_id': {'Borough': 'BROOKLYN', 'Crime_Type': 'VIOLATION'}, '#Crimes': 7321}
# {'_id': {'Borough': 'QUEENS', 'Crime_Type': 'VIOLATION'}, '#Crimes': 5608}
# {'_id': {'Borough': 'BROOKLYN', 'Crime_Type': 'MISDEMEANOR'}, '#Crimes': 15671}
# {'_id': {'Borough': 'STATEN ISLAND', 'Crime_Type': 'VIOLATION'}, '#Crimes': 1161}
# {'_id': {'Borough': 'BRONX', 'Crime_Type': 'FELONY'}, '#Crimes': 6290}
# {'_id': {'Borough': 'STATEN ISLAND', 'Crime_Type': 'FELONY'}, '#Crimes': 1100}
# {'_id': {'Borough': 'BRONX', 'Crime_Type': 'MISDEMEANOR'}, '#Crimes': 11406}
# {'_id': {'Borough': 'MANHATTAN', 'Crime_Type': 'MISDEMEANOR'}, '#Crimes': 15480}

# %%
# Query3: Rank Boroughs by Women Safety
result = mycol.aggregate([
    #Select rows where victim is Female
    { "$match": { "VIC_SEX": 'F' } },

    # Group the documents and "count" via $sum on the values
    { "$group": {
        "_id": {
            "Borough": "$BORO_NM"
        },
        "#Crimes": { "$sum": 1 }
    }},
    
    #Sort results by #Crimes
    { "$sort": { "#Crimes": 1 } }
])
for x in result:
    print(x)
# Out:
# {'_id': {'Borough': 'STATEN ISLAND'}, '#Crimes': 2300}
# {'_id': {'Borough': 'MANHATTAN'}, '#Crimes': 10231}
# {'_id': {'Borough': 'BRONX'}, '#Crimes': 11194}
# {'_id': {'Borough': 'QUEENS'}, '#Crimes': 11347}
# {'_id': {'Borough': 'BROOKLYN'}, '#Crimes': 15233}

# %%
# Query 4: Find Age Group Most Targeted for a particular crime (FRAUDS)
result = mycol.aggregate([
    #Select rows Offense is Fraud
    { "$match": { "OFNS_DESC": 'FRAUDS' } },

    # Group the documents and "count" via $sum on the values
    { "$group": {
        "_id": {
            "VICTIM_AGE_GROUP": "$VIC_AGE_GROUP"
        },
        "#Frauds": { "$sum": 1 }
    }},
    
    #Sort results by #Frauds
    { "$sort": { "#Frauds": -1 } }
])
for x in result:
    print(x)
# Out:
# {'_id': {'VICTIM_AGE_GROUP': 'UNKNOWN'}, '#Frauds': 95}
# {'_id': {'VICTIM_AGE_GROUP': '45-64'}, '#Frauds': 79}
# {'_id': {'VICTIM_AGE_GROUP': '25-44'}, '#Frauds': 72}
# {'_id': {'VICTIM_AGE_GROUP': '65+'}, '#Frauds': 22}
# {'_id': {'VICTIM_AGE_GROUP': '18-24'}, '#Frauds': 16}
# {'_id': {'VICTIM_AGE_GROUP': '<18'}, '#Frauds': 3}

# %%
# Query 5: Average number of crimes committed in each borough in each month
result = mycol.aggregate([
    # Group the documents and "count" via $sum on the values
    { "$group": {
        "_id": {
            "Borough": "$BORO_NM",
            "Month" : { '$month' : { '$toDate': "$CMPLNT_FR_DT" }}
        },
        "#Crimes": { "$sum": 1/30 }
    }},
    { "$sort": { "Month": 1, "Borough": 1 } }
])
for x in result:
    print(x)
# Out:
# {'_id': {'Borough': 'QUEENS', 'Month': 12}, '#Crimes': 10.266666666666666}
# {'_id': {'Borough': 'STATEN ISLAND', 'Month': 4}, '#Crimes': 18.9}
# {'_id': {'Borough': 'QUEENS', 'Month': 2}, '#Crimes': 145.06666666666666}
# {'_id': {'Borough': 'STATEN ISLAND', 'Month': 7}, '#Crimes': 0.23333333333333334}
# {'_id': {'Borough': 'BRONX', 'Month': 8}, '#Crimes': 0.6333333333333333}
# {'_id': {'Borough': 'MANHATTAN', 'Month': 8}, '#Crimes': 1.4}
# {'_id': {'Borough': 'QUEENS', 'Month': 11}, '#Crimes': 3.8}
# {'_id': {'Borough': 'MANHATTAN', 'Month': 4}, '#Crimes': 109.16666666666667}
# {'_id': {'Borough': 'STATEN ISLAND', 'Month': 11}, '#Crimes': 0.5666666666666667}
# {'_id': {'Borough': 'BROOKLYN', 'Month': 7}, '#Crimes': 1.4333333333333333}
# {'_id': {'Borough': 'BROOKLYN', 'Month': 11}, '#Crimes': 4.466666666666667}
# {'_id': {'Borough': 'STATEN ISLAND', 'Month': 12}, '#Crimes': 2.533333333333333}
# {'_id': {'Borough': 'BRONX', 'Month': 5}, '#Crimes': 131.63333333333333}
# {'_id': {'Borough': 'BROOKLYN', 'Month': 2}, '#Crimes': 196.6}
# {'_id': {'Borough': 'BROOKLYN', 'Month': 12}, '#Crimes': 17.166666666666668}
# {'_id': {'Borough': 'BROOKLYN', 'Month': 4}, '#Crimes': 145.6}
# {'_id': {'Borough': 'QUEENS', 'Month': 4}, '#Crimes': 110.2}
# {'_id': {'Borough': 'STATEN ISLAND', 'Month': 2}, '#Crimes': 27.266666666666666}
# {'_id': {'Borough': 'MANHATTAN', 'Month': 3}, '#Crimes': 158.73333333333332}
# {'_id': {'Borough': 'BRONX', 'Month': 10}, '#Crimes': 1.6666666666666667}
# {'_id': {'Borough': 'BRONX', 'Month': 3}, '#Crimes': 123.53333333333333}
# {'_id': {'Borough': 'BRONX', 'Month': 6}, '#Crimes': 126.7}
# {'_id': {'Borough': 'STATEN ISLAND', 'Month': 6}, '#Crimes': 23.6}
# {'_id': {'Borough': 'QUEENS', 'Month': 7}, '#Crimes': 1.1}
# {'_id': {'Borough': 'STATEN ISLAND', 'Month': 1}, '#Crimes': 27.5}
# {'_id': {'Borough': 'BRONX', 'Month': 1}, '#Crimes': 139.96666666666667}
# {'_id': {'Borough': 'BRONX', 'Month': 9}, '#Crimes': 0.8666666666666667}
# {'_id': {'Borough': 'MANHATTAN', 'Month': 5}, '#Crimes': 134.3}
# {'_id': {'Borough': 'STATEN ISLAND', 'Month': 9}, '#Crimes': 0.3}
# {'_id': {'Borough': 'MANHATTAN', 'Month': 6}, '#Crimes': 137.46666666666667}
# {'_id': {'Borough': 'MANHATTAN', 'Month': 1}, '#Crimes': 203.56666666666666}
# {'_id': {'Borough': 'QUEENS', 'Month': 5}, '#Crimes': 140.73333333333332}
# {'_id': {'Borough': 'STATEN ISLAND', 'Month': 10}, '#Crimes': 0.23333333333333334}
# {'_id': {'Borough': 'BROOKLYN', 'Month': 8}, '#Crimes': 1.4666666666666666}
# {'_id': {'Borough': 'STATEN ISLAND', 'Month': 3}, '#Crimes': 24.3}
# {'_id': {'Borough': 'MANHATTAN', 'Month': 10}, '#Crimes': 2.433333333333333}
# {'_id': {'Borough': 'BRONX', 'Month': 11}, '#Crimes': 2.3}
# {'_id': {'Borough': 'BRONX', 'Month': 12}, '#Crimes': 7.833333333333333}
# {'_id': {'Borough': 'QUEENS', 'Month': 8}, '#Crimes': 1.0666666666666667}
# {'_id': {'Borough': 'MANHATTAN', 'Month': 9}, '#Crimes': 1.8666666666666667}
# {'_id': {'Borough': 'STATEN ISLAND', 'Month': 5}, '#Crimes': 21.8}
# {'_id': {'Borough': 'BROOKLYN', 'Month': 5}, '#Crimes': 177.93333333333334}
# {'_id': {'Borough': 'BRONX', 'Month': 2}, '#Crimes': 129.66666666666666}
# {'_id': {'Borough': 'BROOKLYN', 'Month': 10}, '#Crimes': 2.5}
# {'_id': {'Borough': 'QUEENS', 'Month': 10}, '#Crimes': 1.8}
# {'_id': {'Borough': 'STATEN ISLAND', 'Month': 8}, '#Crimes': 0.16666666666666666}
# {'_id': {'Borough': 'BRONX', 'Month': 4}, '#Crimes': 98.53333333333333}
# {'_id': {'Borough': 'MANHATTAN', 'Month': 7}, '#Crimes': 1.3666666666666667}
# {'_id': {'Borough': 'QUEENS', 'Month': 9}, '#Crimes': 1.7333333333333334}
# {'_id': {'Borough': 'BRONX', 'Month': 7}, '#Crimes': 1.0666666666666667}
# {'_id': {'Borough': 'BROOKLYN', 'Month': 3}, '#Crimes': 188.26666666666665}
# {'_id': {'Borough': 'QUEENS', 'Month': 6}, '#Crimes': 136.73333333333332}
# {'_id': {'Borough': 'QUEENS', 'Month': 1}, '#Crimes': 149.6}
# {'_id': {'Borough': 'QUEENS', 'Month': 3}, '#Crimes': 131.83333333333334}
# {'_id': {'Borough': 'BROOKLYN', 'Month': 6}, '#Crimes': 175.63333333333333}
# {'_id': {'Borough': 'BROOKLYN', 'Month': 1}, '#Crimes': 204.7}
# {'_id': {'Borough': 'MANHATTAN', 'Month': 2}, '#Crimes': 187.8}
# {'_id': {'Borough': 'MANHATTAN', 'Month': 12}, '#Crimes': 15.1}
# {'_id': {'Borough': 'MANHATTAN', 'Month': 11}, '#Crimes': 3.6}
# {'_id': {'Borough': 'BROOKLYN', 'Month': 9}, '#Crimes': 2.2666666666666666}

# %%
# Query 6: Look at crimes against underage women
myquery = { "VIC_SEX": "F", 
          "VIC_AGE_GROUP" : '<18'}

mydoc = mycol.find(myquery)

for x in mydoc:
    print(x)
# Out:
# {'_id': ObjectId('5fc69ff4d841acf8ef95a4d0'), 'CMPLNT_NUM': 352716651, 'RPT_DT': '2020-06-24', 'CMPLNT_FR_DT': '2020-06-24', 'CMPLNT_TO_DT': '2020-06-24', 'CMPLNT_FR_TM': '18:45:00', 'CMPLNT_TO_TM': '18:49:00', 'JURIS_DESC': 'N.Y. POLICE DEPT', 'OFFENSE_CLASS_CODE': 109, 'LAW_CAT_CD': 'FELONY', 'OFNS_DESC': 'GRAND LARCENY', 'BORO_NM': 'BROOKLYN', 'PREM_TYP_DESC': 'DEPARTMENT STORE', 'LOC_OF_OCCUR_DESC': 'FRONT OF', 'SUSP_AGE_GROUP': 'UNKNOWN', 'SUSP_RACE': 'BLACK', 'SUSP_SEX': 'M', 'VIC_AGE_GROUP': '<18', 'VIC_RACE': 'WHITE', 'VIC_SEX': 'F'}
# {'_id': ObjectId('5fc69ff4d841acf8ef95a4ea'), 'CMPLNT_NUM': 163815913, 'RPT_DT': '2020-06-25', 'CMPLNT_FR_DT': '2020-06-25', 'CMPLNT_TO_DT': '2020-06-25', 'CMPLNT_FR_TM': '16:30:00', 'CMPLNT_TO_TM': '16:32:00', 'JURIS_DESC': 'N.Y. POLICE DEPT', 'OFFENSE_CLASS_CODE': 578, 'LAW_CAT_CD': 'VIOLATION', 'OFNS_DESC': 'HARRASSMENT 2', 'BORO_NM': 'BRONX', 'PREM_TYP_DESC': 'RESIDENCE-HOUSE', 'LOC_OF_OCCUR_DESC': 'INSIDE', 'SUSP_AGE_GROUP': 'UNKNOWN', 'SUSP_RACE': 'BLACK', 'SUSP_SEX': 'M', 'VIC_AGE_GROUP': '<18', 'VIC_RACE': 'BLACK', 'VIC_SEX': 'F'}
# {'_id': ObjectId('5fc69ff4d841acf8ef95a546'), 'CMPLNT_NUM': 815038096, 'RPT_DT': '2020-06-28', 'CMPLNT_FR_DT': '2020-06-28', 'CMPLNT_TO_DT': '2020-06-28', 'CMPLNT_FR_TM': '21:20:00', 'CMPLNT_TO_TM': '21:32:00', 'JURIS_DESC': 'N.Y. HOUSING POLICE', 'OFFENSE_CLASS_CODE': 344, 'LAW_CAT_CD': 'MISDEMEANOR', 'OFNS_DESC': 'ASSAULT 3 & RELATED OFFENSES', 'BORO_NM': 'MANHATTAN', 'PREM_TYP_DESC': 'RESIDENCE - PUBLIC HOUSING', 'LOC_OF_OCCUR_DESC': 'INSIDE', 'SUSP_AGE_GROUP': '<18', 'SUSP_RACE': 'BLACK', 'SUSP_SEX': 'F', 'VIC_AGE_GROUP': '<18', 'VIC_RACE': 'BLACK', 'VIC_SEX': 'F'}
# {'_id': ObjectId('5fc69ff4d841acf8ef95a5af'), 'CMPLNT_NUM': 566185901, 'RPT_DT': '2020-06-29', 'CMPLNT_FR_DT': '2020-06-27', 'CMPLNT_TO_DT': '2020-06-27', 'CMPLNT_FR_TM': '09:00:00', 'CMPLNT_TO_TM': '13:00:00', 'JURIS_DESC': 'N.Y. POLICE DEPT', 'OFFENSE_CLASS_CODE': 104, 'LAW_CAT_CD': 'FELONY', 'OFNS_DESC': 'RAPE', 'BORO_NM': 'BRONX', 'PREM_TYP_DESC': 'RESIDENCE - APT. HOUSE', 'LOC_OF_OCCUR_DESC': 'INSIDE', 'SUSP_AGE_GROUP': '18-24', 'SUSP_RACE': 'BLACK HISPANIC', 'SUSP_SEX': 'M', 'VIC_AGE_GROUP': '<18', 'VIC_RACE': 'BLACK HISPANIC', 'VIC_SEX': 'F'}
# {'_id': ObjectId('5fc69ff4d841acf8ef95a5bc'), 'CMPLNT_NUM': 441601413, 'RPT_DT': '2020-06-24', 'CMPLNT_FR_DT': '2020-06-24', 'CMPLNT_TO_DT': '2020-06-24', 'CMPLNT_FR_TM': '00:55:00', 'CMPLNT_TO_TM': '00:56:00', 'JURIS_DESC': 'N.Y. POLICE DEPT', 'OFFENSE_CLASS_CODE': 361, 'LAW_CAT_CD': 'MISDEMEANOR', 'OFNS_DESC': 'OFF. AGNST PUB ORD SENSBLTY &', 'BORO_NM': 'MANHATTAN', 'PREM_TYP_DESC': 'RESIDENCE - APT. HOUSE', 'LOC_OF_OCCUR_DESC': 'INSIDE', 'SUSP_AGE_GROUP': 'UNKNOWN', 'SUSP_RACE': 'UNKNOWN', 'SUSP_SEX': 'U', 'VIC_AGE_GROUP': '<18', 'VIC_RACE': 'WHITE HISPANIC', 'VIC_SEX': 'F'}
# {'_id': ObjectId('5fc69ff4d841acf8ef95a5cb'), 'CMPLNT_NUM': 622915159, 'RPT_DT': '2020-06-24', 'CMPLNT_FR_DT': '2020-06-24', 'CMPLNT_TO_DT': '2020-06-24', 'CMPLNT_FR_TM': '08:00:00', 'CMPLNT_TO_TM': '08:45:00', 'JURIS_DESC': 'N.Y. POLICE DEPT', 'OFFENSE_CLASS_CODE': 348, 'LAW_CAT_CD': 'MISDEMEANOR', 'OFNS_DESC': 'VEHICLE AND TRAFFIC LAWS', 'BORO_NM': 'BROOKLYN', 'PREM_TYP_DESC': 'STREET', 'LOC_OF_OCCUR_DESC': 'FRONT OF', 'SUSP_AGE_GROUP': '18-24', 'SUSP_RACE': 'BLACK', 'SUSP_SEX': 'M', 'VIC_AGE_GROUP': '<18', 'VIC_RACE': 'BLACK', 'VIC_SEX': 'F'}
# {'_id': ObjectId('5fc69ff4d841acf8ef95a5cc'), 'CMPLNT_NUM': 129030241, 'RPT_DT': '2020-06-24', 'CMPLNT_FR_DT': '2020-06-24', 'CMPLNT_TO_DT': '2020-06-24', 'CMPLNT_FR_TM': '18:07:00', 'CMPLNT_TO_TM': '19:07:00', 'JURIS_DESC': 'N.Y. POLICE DEPT', 'OFFENSE_CLASS_CODE': 365, 'LAW_CAT_CD': 'MISDEMEANOR', 'OFNS_DESC': 'ADMINISTRATIVE CODE', 'BORO_NM': 'BRONX', 'PREM_TYP_DESC': 'RESIDENCE - APT. HOUSE', 'LOC_OF_OCCUR_DESC': 'INSIDE', 'SUSP_AGE_GROUP': 'UNKNOWN', 'SUSP_RACE': 'UNKNOWN', 'SUSP_SEX': 'M', 'VIC_AGE_GROUP': '<18', 'VIC_RACE': 'WHITE HISPANIC', 'VIC_SEX': 'F'}
# {'_id': ObjectId('5fc69ff4d841acf8ef95a5dc'), 'CMPLNT_NUM': 487754399, 'RPT_DT': '2020-06-25', 'CMPLNT_FR_DT': '2020-06-08', 'CMPLNT_TO_DT': '2020-06-15', 'CMPLNT_FR_TM': '10:30:00', 'CMPLNT_TO_TM': '21:50:00', 'JURIS_DESC': 'N.Y. POLICE DEPT', 'OFFENSE_CLASS_CODE': 344, 'LAW_CAT_CD': 'MISDEMEANOR', 'OFNS_DESC': 'ASSAULT 3 & RELATED OFFENSES', 'BORO_NM': 'QUEENS', 'PREM_TYP_DESC': 'RESIDENCE - APT. HOUSE', 'LOC_OF_OCCUR_DESC': 'INSIDE', 'SUSP_AGE_GROUP': '65+', 'SUSP_RACE': 'BLACK', 'SUSP_SEX': 'F', 'VIC_AGE_GROUP': '<18', 'VIC_RACE': 'BLACK', 'VIC_SEX': 'F'}
# {'_id': ObjectId('5fc69ff4d841acf8ef95a617'), 'CMPLNT_NUM': 541472438, 'RPT_DT': '2020-06-25', 'CMPLNT_FR_DT': '2020-06-25', 'CMPLNT_TO_DT': '2020-06-25', 'CMPLNT_FR_TM': '22:00:00', 'CMPLNT_TO_TM': '22:16:00', 'JURIS_DESC': 'N.Y. POLICE DEPT', 'OFFENSE_CLASS_CODE': 106, 'LAW_CAT_CD': 'FELONY', 'OFNS_DESC': 'FELONY ASSAULT', 'BORO_NM': 'BRONX', 'PREM_TYP_DESC': 'RESIDENCE-HOUSE', 'LOC_OF_OCCUR_DESC': 'INSIDE', 'SUSP_AGE_GROUP': '25-44', 'SUSP_RACE': 'BLACK', 'SUSP_SEX': 'M', 'VIC_AGE_GROUP': '<18', 'VIC_RACE': 'BLACK', 'VIC_SEX': 'F'}
# {'_id': ObjectId('5fc69ff4d841acf8ef95a61c'), 'CMPLNT_NUM': 219992476, 'RPT_DT': '2020-06-28', 'CMPLNT_FR_DT': '2020-06-28', 'CMPLNT_TO_DT': '2020-06-28', 'CMPLNT_FR_TM': '14:30:00', 'CMPLNT_TO_TM': '14:49:00', 'JURIS_DESC': 'N.Y. POLICE DEPT', 'OFFENSE_CLASS_CODE': 578, 'LAW_CAT_CD': 'VIOLATION', 'OFNS_DESC': 'HARRASSMENT 2', 'BORO_NM': 'BROOKLYN', 'PREM_TYP_DESC': 'RESIDENCE - APT. HOUSE', 'LOC_OF_OCCUR_DESC': 'INSIDE', 'SUSP_AGE_GROUP': 'UNKNOWN', 'SUSP_RACE': 'WHITE', 'SUSP_SEX': 'M', 'VIC_AGE_GROUP': '<18', 'VIC_RACE': 'UNKNOWN', 'VIC_SEX': 'F'}
# {'_id': ObjectId('5fc69ff4d841acf8ef95a628'), 'CMPLNT_NUM': 867217447, 'RPT_DT': '2020-06-23', 'CMPLNT_FR_DT': '2020-06-23', 'CMPLNT_TO_DT': '2020-06-23', 'CMPLNT_FR_TM': '13:00:00', 'CMPLNT_TO_TM': '13:15:00', 'JURIS_DESC': 'N.Y. POLICE DEPT', 'OFFENSE_CLASS_CODE': 578, 'LAW_CAT_CD': 'VIOLATION', 'OFNS_DESC': 'HARRASSMENT 2', 'BORO_NM': 'STATEN ISLAND', 'PREM_TYP_DESC': 'STREET', 'LOC_OF_OCCUR_DESC': 'FRONT OF', 'SUSP_AGE_GROUP': '65+', 'SUSP_RACE': 'ASIAN / PACIFIC ISLANDER', 'SUSP_SEX': 'U', 'VIC_AGE_GROUP': '<18', 'VIC_RACE': 'WHITE', 'VIC_SEX': 'F'}
# {'_id': ObjectId('5fc69ff4d841acf8ef95a644'), 'CMPLNT_NUM': 995272559, 'RPT_DT': '2020-06-29', 'CMPLNT_FR_DT': '2013-06-29', 'CMPLNT_TO_DT': '2014-06-29', 'CMPLNT_FR_TM': '00:01:00', 'CMPLNT_TO_TM': '23:59:00', 'JURIS_DESC': 'N.Y. POLICE DEPT', 'OFFENSE_CLASS_CODE': 116, 'LAW_CAT_CD': 'FELONY', 'OFNS_DESC': 'SEX CRIMES', 'BORO_NM': 'QUEENS', 'PREM_TYP_DESC': 'RESIDENCE - APT. HOUSE', 'LOC_OF_OCCUR_DESC': 'INSIDE', 'SUSP_AGE_GROUP': '25-44', 'SUSP_RACE': 'WHITE', 'SUSP_SEX': 'M', 'VIC_AGE_GROUP': '<18', 'VIC_RACE': 'WHITE', 'VIC_SEX': 'F'}
# {'_id': ObjectId('5fc69ff4d841acf8ef95a6de'), 'CMPLNT_NUM': 473447903, 'RPT_DT': '2020-06-25', 'CMPLNT_FR_DT': '2020-06-24', 'CMPLNT_TO_DT': '2020-06-25', 'CMPLNT_FR_TM': '21:00:00', 'CMPLNT_TO_TM': '12:00:00', 'JURIS_DESC': 'N.Y. POLICE DEPT', 'OFFENSE_CLASS_CODE': 341, 'LAW_CAT_CD': 'MISDEMEANOR', 'OFNS_DESC': 'PETIT LARCENY', 'BORO_NM': 'BROOKLYN', 'PREM_TYP_DESC': 'STREET', 'LOC_OF_OCCUR_DESC': 'FRONT OF', 'SUSP_AGE_GROUP': 'UNKNOWN', 'SUSP_RACE': 'UNKNOWN', 'SUSP_SEX': 'U', 'VIC_AGE_GROUP': '<18', 'VIC_RACE': 'WHITE', 'VIC_SEX': 'F'}
# {'_id': ObjectId('5fc69ff4d841acf8ef95a71a'), 'CMPLNT_NUM': 541374973, 'RPT_DT': '2020-06-25', 'CMPLNT_FR_DT': '2020-06-25', 'CMPLNT_TO_DT': '2020-06-25', 'CMPLNT_FR_TM': '18:00:00', 'CMPLNT_TO_TM': '18:10:00', 'JURIS_DESC': 'N.Y. POLICE DEPT', 'OFFENSE_CLASS_CODE': 578, 'LAW_CAT_CD': 'VIOLATION', 'OFNS_DESC': 'HARRASSMENT 2', 'BORO_NM': 'QUEENS', 'PREM_TYP_DESC': 'RESIDENCE-HOUSE', 'LOC_OF_OCCUR_DESC': 'INSIDE', 'SUSP_AGE_GROUP': '18-24', 'SUSP_RACE': 'WHITE', 'SUSP_SEX': 'M', 'VIC_AGE_GROUP': '<18', 'VIC_RACE': 'WHITE', 'VIC_SEX': 'F'}
# {'_id': ObjectId('5fc69ff4d841acf8ef95a71d'), 'CMPLNT_NUM': 670046587, 'RPT_DT': '2020-06-25', 'CMPLNT_FR_DT': '2020-06-25', 'CMPLNT_TO_DT': '2020-06-25', 'CMPLNT_FR_TM': '21:45:00', 'CMPLNT_TO_TM': '22:00:00', 'JURIS_DESC': 'N.Y. POLICE DEPT', 'OFFENSE_CLASS_CODE': 578, 'LAW_CAT_CD': 'VIOLATION', 'OFNS_DESC': 'HARRASSMENT 2', 'BORO_NM': 'MANHATTAN', 'PREM_TYP_DESC': 'STREET', 'LOC_OF_OCCUR_DESC': 'FRONT OF', 'SUSP_AGE_GROUP': '18-24', 'SUSP_RACE': 'BLACK', 'SUSP_SEX': 'M', 'VIC_AGE_GROUP': '<18', 'VIC_RACE': 'BLACK', 'VIC_SEX': 'F'}
# {'_id': ObjectId('5fc69ff4d841acf8ef95a71f'), 'CMPLNT_NUM': 817549419, 'RPT_DT': '2020-06-24', 'CMPLNT_FR_DT': '2018-09-01', 'CMPLNT_TO_DT': '2020-01-03', 'CMPLNT_FR_TM': '00:01:00', 'CMPLNT_TO_TM': '00:01:00', 'JURIS_DESC': 'N.Y. POLICE DEPT', 'OFFENSE_CLASS_CODE': 116, 'LAW_CAT_CD': 'FELONY', 'OFNS_DESC': 'SEX CRIMES', 'BORO_NM': 'QUEENS', 'PREM_TYP_DESC': 'RESIDENCE - APT. HOUSE', 'LOC_OF_OCCUR_DESC': 'INSIDE', 'SUSP_AGE_GROUP': '25-44', 'SUSP_RACE': 'WHITE HISPANIC', 'SUSP_SEX': 'M', 'VIC_AGE_GROUP': '<18', 'VIC_RACE': 'WHITE HISPANIC', 'VIC_SEX': 'F'}
# {'_id': ObjectId('5fc69ff4d841acf8ef95a74c'), 'CMPLNT_NUM': 106714519, 'RPT_DT': '2020-06-28', 'CMPLNT_FR_DT': '2020-06-27', 'CMPLNT_TO_DT': '2020-06-27', 'CMPLNT_FR_TM': '22:00:00', 'CMPLNT_TO_TM': '22:05:00', 'JURIS_DESC': 'N.Y. HOUSING POLICE', 'OFFENSE_CLASS_CODE': 578, 'LAW_CAT_CD': 'VIOLATION', 'OFNS_DESC': 'HARRASSMENT 2', 'BORO_NM': 'QUEENS', 'PREM_TYP_DESC': 'RESIDENCE - PUBLIC HOUSING', 'LOC_OF_OCCUR_DESC': 'FRONT OF', 'SUSP_AGE_GROUP': 'UNKNOWN', 'SUSP_RACE': 'BLACK HISPANIC', 'SUSP_SEX': 'M', 'VIC_AGE_GROUP': '<18', 'VIC_RACE': 'WHITE HISPANIC', 'VIC_SEX': 'F'}
# {'_id': ObjectId('5fc69ff4d841acf8ef95a75f'), 'CMPLNT_NUM': 763539646, 'RPT_DT': '2020-06-29', 'CMPLNT_FR_DT': '2020-06-28', 'CMPLNT_TO_DT': '2020-06-28', 'CMPLNT_FR_TM': '09:30:00', 'CMPLNT_TO_TM': '10:00:00', 'JURIS_DESC': 'N.Y. POLICE DEPT', 'OFFENSE_CLASS_CODE': 578, 'LAW_CAT_CD': 'VIOLATION', 'OFNS_DESC': 'HARRASSMENT 2', 'BORO_NM': 'BROOKLYN', 'PREM_TYP_DESC': 'RESIDENCE-HOUSE', 'LOC_OF_OCCUR_DESC': 'INSIDE', 'SUSP_AGE_GROUP': 'UNKNOWN', 'SUSP_RACE': 'UNKNOWN', 'SUSP_SEX': 'U', 'VIC_AGE_GROUP': '<18', 'VIC_RACE': 'WHITE HISPANIC', 'VIC_SEX': 'F'}
# {'_id': ObjectId('5fc69ff4d841acf8ef95a771'), 'CMPLNT_NUM': 105508488, 'RPT_DT': '2020-06-28', 'CMPLNT_FR_DT': '2020-06-28', 'CMPLNT_TO_DT': '2020-06-28', 'CMPLNT_FR_TM': '02:00:00', 'CMPLNT_TO_TM': '02:05:00', 'JURIS_DESC': 'N.Y. POLICE DEPT', 'OFFENSE_CLASS_CODE': 578, 'LAW_CAT_CD': 'VIOLATION', 'OFNS_DESC': 'HARRASSMENT 2', 'BORO_NM': 'MANHATTAN', 'PREM_TYP_DESC': 'RESIDENCE - APT. HOUSE', 'LOC_OF_OCCUR_DESC': 'INSIDE', 'SUSP_AGE_GROUP': '45-64', 'SUSP_RACE': 'WHITE', 'SUSP_SEX': 'M', 'VIC_AGE_GROUP': '<18', 'VIC_RACE': 'ASIAN / PACIFIC ISLANDER', 'VIC_SEX': 'F'}
# {'_id': ObjectId('5fc69ff4d841acf8ef95a775'), 'CMPLNT_NUM': 705255276, 'RPT_DT': '2020-06-21', 'CMPLNT_FR_DT': '2020-06-21', 'CMPLNT_TO_DT': '2020-06-21', 'CMPLNT_FR_TM': '17:10:00', 'CMPLNT_TO_TM': '17:15:00', 'JURIS_DESC': 'N.Y. POLICE DEPT', 'OFFENSE_CLASS_CODE': 578, 'LAW_CAT_CD': 'VIOLATION', 'OFNS_DESC': 'HARRASSMENT 2', 'BORO_NM': 'STATEN ISLAND', 'PREM_TYP_DESC': 'RESIDENCE-HOUSE', 'LOC_OF_OCCUR_DESC': 'INSIDE', 'SUSP_AGE_GROUP': '18-24', 'SUSP_RACE': 'BLACK', 'SUSP_SEX': 'F', 'VIC_AGE_GROUP': '<18', 'VIC_RACE': 'WHITE', 'VIC_SEX': 'F'}
# {'_id': ObjectId('5fc69ff4d841acf8ef95a7ac'), 'CMPLNT_NUM': 350680110, 'RPT_DT': '2020-06-30', 'CMPLNT_FR_DT': '2020-06-30', 'CMPLNT_TO_DT': '2020-06-30', 'CMPLNT_FR_TM': '14:00:00', 'CMPLNT_TO_TM': '15:00:00', 'JURIS_DESC': 'N.Y. POLICE DEPT', 'OFFENSE_CLASS_CODE': 344, 'LAW_CAT_CD': 'MISDEMEANOR', 'OFNS_DESC': 'ASSAULT 3 & RELATED OFFENSES', 'BORO_NM': 'BRONX', 'PREM_TYP_DESC': 'RESIDENCE - APT. HOUSE', 'LOC_OF_OCCUR_DESC': 'INSIDE', 'SUSP_AGE_GROUP': '18-24', 'SUSP_RACE': 'WHITE HISPANIC', 'SUSP_SEX': 'M', 'VIC_AGE_GROUP': '<18', 'VIC_RACE': 'BLACK HISPANIC', 'VIC_SEX': 'F'}
# {'_id': ObjectId('5fc69ff4d841acf8ef95a82a'), 'CMPLNT_NUM': 313398769, 'RPT_DT': '2020-06-23', 'CMPLNT_FR_DT': '2020-06-13', 'CMPLNT_TO_DT': '2020-06-13', 'CMPLNT_FR_TM': '21:30:00', 'CMPLNT_TO_TM': '21:45:00', 'JURIS_DESC': 'N.Y. POLICE DEPT', 'OFFENSE_CLASS_CODE': 578, 'LAW_CAT_CD': 'VIOLATION', 'OFNS_DESC': 'HARRASSMENT 2', 'BORO_NM': 'QUEENS', 'PREM_TYP_DESC': 'STREET', 'LOC_OF_OCCUR_DESC': 'FRONT OF', 'SUSP_AGE_GROUP': '18-24', 'SUSP_RACE': 'BLACK', 'SUSP_SEX': 'F', 'VIC_AGE_GROUP': '<18', 'VIC_RACE': 'BLACK', 'VIC_SEX': 'F'}
# {'_id': ObjectId('5fc69ff4d841acf8ef95a8bd'), 'CMPLNT_NUM': 793199295, 'RPT_DT': '2020-06-27', 'CMPLNT_FR_DT': '2020-06-26', 'CMPLNT_TO_DT': '2020-06-26', 'CMPLNT_FR_TM': '16:30:00', 'CMPLNT_TO_TM': '17:00:00', 'JURIS_DESC': 'N.Y. POLICE DEPT', 'OFFENSE_CLASS_CODE': 578, 'LAW_CAT_CD': 'VIOLATION', 'OFNS_DESC': 'HARRASSMENT 2', 'BORO_NM': 'BROOKLYN', 'PREM_TYP_DESC': 'PARK/PLAYGROUND', 'LOC_OF_OCCUR_DESC': 'INSIDE', 'SUSP_AGE_GROUP': '25-44', 'SUSP_RACE': 'BLACK', 'SUSP_SEX': 'F', 'VIC_AGE_GROUP': '<18', 'VIC_RACE': 'BLACK', 'VIC_SEX': 'F'}
# {'_id': ObjectId('5fc69ff4d841acf8ef95a8e1'), 'CMPLNT_NUM': 737714013, 'RPT_DT': '2020-06-22', 'CMPLNT_FR_DT': '2020-06-22', 'CMPLNT_TO_DT': '2020-06-22', 'CMPLNT_FR_TM': '02:50:00', 'CMPLNT_TO_TM': '03:30:00', 'JURIS_DESC': 'N.Y. HOUSING POLICE', 'OFFENSE_CLASS_CODE': 344, 'LAW_CAT_CD': 'MISDEMEANOR', 'OFNS_DESC': 'ASSAULT 3 & RELATED OFFENSES', 'BORO_NM': 'MANHATTAN', 'PREM_TYP_DESC': 'RESIDENCE - PUBLIC HOUSING', 'LOC_OF_OCCUR_DESC': 'INSIDE', 'SUSP_AGE_GROUP': '25-44', 'SUSP_RACE': 'BLACK', 'SUSP_SEX': 'F', 'VIC_AGE_GROUP': '<18', 'VIC_RACE': 'BLACK', 'VIC_SEX': 'F'}
# {'_id': ObjectId('5fc69ff4d841acf8ef95a8e6'), 'CMPLNT_NUM': 391869544, 'RPT_DT': '2020-06-26', 'CMPLNT_FR_DT': '2020-06-25', 'CMPLNT_TO_DT': '2020-06-25', 'CMPLNT_FR_TM': '23:30:00', 'CMPLNT_TO_TM': '23:45:00', 'JURIS_DESC': 'N.Y. POLICE DEPT', 'OFFENSE_CLASS_CODE': 233, 'LAW_CAT_CD': 'MISDEMEANOR', 'OFNS_DESC': 'SEX CRIMES', 'BORO_NM': 'QUEENS', 'PREM_TYP_DESC': 'RESIDENCE - APT. HOUSE', 'LOC_OF_OCCUR_DESC': 'INSIDE', 'SUSP_AGE_GROUP': '25-44', 'SUSP_RACE': 'BLACK', 'SUSP_SEX': 'F', 'VIC_AGE_GROUP': '<18', 'VIC_RACE': 'BLACK', 'VIC_SEX': 'F'}
# {'_id': ObjectId('5fc69ff4d841acf8ef95a975'), 'CMPLNT_NUM': 268097478, 'RPT_DT': '2020-06-30', 'CMPLNT_FR_DT': '2020-06-30', 'CMPLNT_TO_DT': '2020-06-30', 'CMPLNT_FR_TM': '20:20:00', 'CMPLNT_TO_TM': '20:25:00', 'JURIS_DESC': 'N.Y. HOUSING POLICE', 'OFFENSE_CLASS_CODE': 578, 'LAW_CAT_CD': 'VIOLATION', 'OFNS_DESC': 'HARRASSMENT 2', 'BORO_NM': 'BROOKLYN', 'PREM_TYP_DESC': 'RESIDENCE - PUBLIC HOUSING', 'LOC_OF_OCCUR_DESC': 'INSIDE', 'SUSP_AGE_GROUP': '<18', 'SUSP_RACE': 'BLACK HISPANIC', 'SUSP_SEX': 'M', 'VIC_AGE_GROUP': '<18', 'VIC_RACE': 'BLACK HISPANIC', 'VIC_SEX': 'F'}
# {'_id': ObjectId('5fc69ff4d841acf8ef95a9b3'), 'CMPLNT_NUM': 974070194, 'RPT_DT': '2020-06-23', 'CMPLNT_FR_DT': '2020-06-23', 'CMPLNT_TO_DT': '2020-06-23', 'CMPLNT_FR_TM': '14:00:00', 'CMPLNT_TO_TM': '14:10:00', 'JURIS_DESC': 'N.Y. HOUSING POLICE', 'OFFENSE_CLASS_CODE': 106, 'LAW_CAT_CD': 'FELONY', 'OFNS_DESC': 'FELONY ASSAULT', 'BORO_NM': 'MANHATTAN', 'PREM_TYP_DESC': 'RESIDENCE - PUBLIC HOUSING', 'LOC_OF_OCCUR_DESC': 'INSIDE', 'SUSP_AGE_GROUP': '25-44', 'SUSP_RACE': 'BLACK HISPANIC', 'SUSP_SEX': 'F', 'VIC_AGE_GROUP': '<18', 'VIC_RACE': 'BLACK', 'VIC_SEX': 'F'}
# {'_id': ObjectId('5fc69ff4d841acf8ef95aa4b'), 'CMPLNT_NUM': 766128855, 'RPT_DT': '2020-06-24', 'CMPLNT_FR_DT': '2016-06-01', 'CMPLNT_TO_DT': '2020-01-06', 'CMPLNT_FR_TM': '00:01:00', 'CMPLNT_TO_TM': '00:01:00', 'JURIS_DESC': 'N.Y. POLICE DEPT', 'OFFENSE_CLASS_CODE': 116, 'LAW_CAT_CD': 'FELONY', 'OFNS_DESC': 'SEX CRIMES', 'BORO_NM': 'QUEENS', 'PREM_TYP_DESC': 'RESIDENCE - APT. HOUSE', 'LOC_OF_OCCUR_DESC': 'INSIDE', 'SUSP_AGE_GROUP': '25-44', 'SUSP_RACE': 'WHITE HISPANIC', 'SUSP_SEX': 'M', 'VIC_AGE_GROUP': '<18', 'VIC_RACE': 'WHITE HISPANIC', 'VIC_SEX': 'F'}
# {'_id': ObjectId('5fc69ff4d841acf8ef95aa7a'), 'CMPLNT_NUM': 434799671, 'RPT_DT': '2020-06-30', 'CMPLNT_FR_DT': '2020-06-29', 'CMPLNT_TO_DT': '2020-06-29', 'CMPLNT_FR_TM': '21:20:00', 'CMPLNT_TO_TM': '21:30:00', 'JURIS_DESC': 'N.Y. POLICE DEPT', 'OFFENSE_CLASS_CODE': 578, 'LAW_CAT_CD': 'VIOLATION', 'OFNS_DESC': 'HARRASSMENT 2', 'BORO_NM': 'QUEENS', 'PREM_TYP_DESC': 'RESIDENCE - APT. HOUSE', 'LOC_OF_OCCUR_DESC': 'FRONT OF', 'SUSP_AGE_GROUP': '25-44', 'SUSP_RACE': 'WHITE', 'SUSP_SEX': 'M', 'VIC_AGE_GROUP': '<18', 'VIC_RACE': 'WHITE', 'VIC_SEX': 'F'}
# {'_id': ObjectId('5fc69ff4d841acf8ef95aad4'), 'CMPLNT_NUM': 293217073, 'RPT_DT': '2020-06-29', 'CMPLNT_FR_DT': '2019-09-01', 'CMPLNT_TO_DT': '2020-06-27', 'CMPLNT_FR_TM': '12:00:00', 'CMPLNT_TO_TM': '23:59:00', 'JURIS_DESC': 'N.Y. POLICE DEPT', 'OFFENSE_CLASS_CODE': 104, 'LAW_CAT_CD': 'FELONY', 'OFNS_DESC': 'RAPE', 'BORO_NM': 'BROOKLYN', 'PREM_TYP_DESC': 'RESIDENCE-HOUSE', 'LOC_OF_OCCUR_DESC': 'INSIDE', 'SUSP_AGE_GROUP': '18-24', 'SUSP_RACE': 'UNKNOWN', 'SUSP_SEX': 'M', 'VIC_AGE_GROUP': '<18', 'VIC_RACE': 'BLACK HISPANIC', 'VIC_SEX': 'F'}
# {'_id': ObjectId('5fc69ff4d841acf8ef95aad8'), 'CMPLNT_NUM': 855548195, 'RPT_DT': '2020-06-24', 'CMPLNT_FR_DT': '2020-06-24', 'CMPLNT_TO_DT': '2020-06-24', 'CMPLNT_FR_TM': '19:54:00', 'CMPLNT_TO_TM': '20:00:00', 'JURIS_DESC': 'N.Y. POLICE DEPT', 'OFFENSE_CLASS_CODE': 578, 'LAW_CAT_CD': 'VIOLATION', 'OFNS_DESC': 'HARRASSMENT 2', 'BORO_NM': 'MANHATTAN', 'PREM_TYP_DESC': 'RESIDENCE - APT. HOUSE', 'LOC_OF_OCCUR_DESC': 'INSIDE', 'SUSP_AGE_GROUP': 'UNKNOWN', 'SUSP_RACE': 'BLACK', 'SUSP_SEX': 'F', 'VIC_AGE_GROUP': '<18', 'VIC_RACE': 'BLACK', 'VIC_SEX': 'F'}
# {'_id': ObjectId('5fc69ff4d841acf8ef95aae2'), 'CMPLNT_NUM': 527843231, 'RPT_DT': '2020-06-29', 'CMPLNT_FR_DT': '2020-06-27', 'CMPLNT_TO_DT': '2020-06-29', 'CMPLNT_FR_TM': '02:00:00', 'CMPLNT_TO_TM': '02:10:00', 'JURIS_DESC': 'N.Y. POLICE DEPT', 'OFFENSE_CLASS_CODE': 233, 'LAW_CAT_CD': 'MISDEMEANOR', 'OFNS_DESC': 'SEX CRIMES', 'BORO_NM': 'MANHATTAN', 'PREM_TYP_DESC': 'HOTEL/MOTEL', 'LOC_OF_OCCUR_DESC': 'INSIDE', 'SUSP_AGE_GROUP': '25-44', 'SUSP_RACE': 'BLACK HISPANIC', 'SUSP_SEX': 'M', 'VIC_AGE_GROUP': '<18', 'VIC_RACE': 'BLACK HISPANIC', 'VIC_SEX': 'F'}
# {'_id': ObjectId('5fc69ff4d841acf8ef95ab81'), 'CMPLNT_NUM': 194027696, 'RPT_DT': '2020-06-26', 'CMPLNT_FR_DT': '2020-06-24', 'CMPLNT_TO_DT': '2020-06-24', 'CMPLNT_FR_TM': '17:00:00', 'CMPLNT_TO_TM': '17:30:00', 'JURIS_DESC': 'N.Y. POLICE DEPT', 'OFFENSE_CLASS_CODE': 361, 'LAW_CAT_CD': 'MISDEMEANOR', 'OFNS_DESC': 'OFF. AGNST PUB ORD SENSBLTY &', 'BORO_NM': 'BROOKLYN', 'PREM_TYP_DESC': 'RESIDENCE - APT. HOUSE', 'LOC_OF_OCCUR_DESC': 'FRONT OF', 'SUSP_AGE_GROUP': 'UNKNOWN', 'SUSP_RACE': 'BLACK', 'SUSP_SEX': 'F', 'VIC_AGE_GROUP': '<18', 'VIC_RACE': 'UNKNOWN', 'VIC_SEX': 'F'}
# {'_id': ObjectId('5fc69ff4d841acf8ef95abc7'), 'CMPLNT_NUM': 338608191, 'RPT_DT': '2020-06-30', 'CMPLNT_FR_DT': '2020-06-30', 'CMPLNT_TO_DT': '2020-06-30', 'CMPLNT_FR_TM': '20:00:00', 'CMPLNT_TO_TM': '20:10:00', 'JURIS_DESC': 'N.Y. POLICE DEPT', 'OFFENSE_CLASS_CODE': 344, 'LAW_CAT_CD': 'MISDEMEANOR', 'OFNS_DESC': 'ASSAULT 3 & RELATED OFFENSES', 'BORO_NM': 'QUEENS', 'PREM_TYP_DESC': 'RESIDENCE-HOUSE', 'LOC_OF_OCCUR_DESC': 'INSIDE', 'SUSP_AGE_GROUP': '45-64', 'SUSP_RACE': 'BLACK', 'SUSP_SEX': 'M', 'VIC_AGE_GROUP': '<18', 'VIC_RACE': 'BLACK', 'VIC_SEX': 'F'}
# {'_id': ObjectId('5fc69ff4d841acf8ef95ac10'), 'CMPLNT_NUM': 187530737, 'RPT_DT': '2020-06-27', 'CMPLNT_FR_DT': '2020-06-27', 'CMPLNT_TO_DT': '2020-06-27', 'CMPLNT_FR_TM': '01:30:00', 'CMPLNT_TO_TM': '01:45:00', 'JURIS_DESC': 'N.Y. POLICE DEPT', 'OFFENSE_CLASS_CODE': 233, 'LAW_CAT_CD': 'MISDEMEANOR', 'OFNS_DESC': 'SEX CRIMES', 'BORO_NM': 'QUEENS', 'PREM_TYP_DESC': 'RESIDENCE - APT. HOUSE', 'LOC_OF_OCCUR_DESC': 'INSIDE', 'SUSP_AGE_GROUP': '25-44', 'SUSP_RACE': 'WHITE HISPANIC', 'SUSP_SEX': 'M', 'VIC_AGE_GROUP': '<18', 'VIC_RACE': 'WHITE HISPANIC', 'VIC_SEX': 'F'}
# {'_id': ObjectId('5fc69ff4d841acf8ef95ac4c'), 'CMPLNT_NUM': 380416814, 'RPT_DT': '2020-06-29', 'CMPLNT_FR_DT': '2020-06-29', 'CMPLNT_TO_DT': '2020-06-29', 'CMPLNT_FR_TM': '22:15:00', 'CMPLNT_TO_TM': '22:20:00', 'JURIS_DESC': 'N.Y. POLICE DEPT', 'OFFENSE_CLASS_CODE': 578, 'LAW_CAT_CD': 'VIOLATION', 'OFNS_DESC': 'HARRASSMENT 2', 'BORO_NM': 'QUEENS', 'PREM_TYP_DESC': 'RESIDENCE-HOUSE', 'LOC_OF_OCCUR_DESC': 'REAR OF', 'SUSP_AGE_GROUP': '25-44', 'SUSP_RACE': 'BLACK', 'SUSP_SEX': 'F', 'VIC_AGE_GROUP': '<18', 'VIC_RACE': 'BLACK', 'VIC_SEX': 'F'}
# {'_id': ObjectId('5fc69ff4d841acf8ef95aca5'), 'CMPLNT_NUM': 390495612, 'RPT_DT': '2020-06-23', 'CMPLNT_FR_DT': '2020-06-23', 'CMPLNT_TO_DT': '2020-06-23', 'CMPLNT_FR_TM': '07:12:00', 'CMPLNT_TO_TM': '07:13:00', 'JURIS_DESC': 'N.Y. POLICE DEPT', 'OFFENSE_CLASS_CODE': 341, 'LAW_CAT_CD': 'MISDEMEANOR', 'OFNS_DESC': 'PETIT LARCENY', 'BORO_NM': 'QUEENS', 'PREM_TYP_DESC': 'RESIDENCE - APT. HOUSE', 'LOC_OF_OCCUR_DESC': 'INSIDE', 'SUSP_AGE_GROUP': '45-64', 'SUSP_RACE': 'WHITE', 'SUSP_SEX': 'F', 'VIC_AGE_GROUP': '<18', 'VIC_RACE': 'WHITE HISPANIC', 'VIC_SEX': 'F'}
# {'_id': ObjectId('5fc69ff4d841acf8ef95ace1'), 'CMPLNT_NUM': 883200488, 'RPT_DT': '2020-06-23', 'CMPLNT_FR_DT': '2020-06-22', 'CMPLNT_TO_DT': '2020-06-22', 'CMPLNT_FR_TM': '18:00:00', 'CMPLNT_TO_TM': '18:10:00', 'JURIS_DESC': 'N.Y. POLICE DEPT', 'OFFENSE_CLASS_CODE': 578, 'LAW_CAT_CD': 'VIOLATION', 'OFNS_DESC': 'HARRASSMENT 2', 'BORO_NM': 'QUEENS', 'PREM_TYP_DESC': 'FOOD SUPERMARKET', 'LOC_OF_OCCUR_DESC': 'INSIDE', 'SUSP_AGE_GROUP': '18-24', 'SUSP_RACE': 'WHITE HISPANIC', 'SUSP_SEX': 'U', 'VIC_AGE_GROUP': '<18', 'VIC_RACE': 'WHITE HISPANIC', 'VIC_SEX': 'F'}
# {'_id': ObjectId('5fc69ff4d841acf8ef95ad3f'), 'CMPLNT_NUM': 881062315, 'RPT_DT': '2020-06-30', 'CMPLNT_FR_DT': '2020-06-29', 'CMPLNT_TO_DT': '2020-06-29', 'CMPLNT_FR_TM': '13:00:00', 'CMPLNT_TO_TM': '23:50:00', 'JURIS_DESC': 'N.Y. POLICE DEPT', 'OFFENSE_CLASS_CODE': 116, 'LAW_CAT_CD': 'FELONY', 'OFNS_DESC': 'SEX CRIMES', 'BORO_NM': 'BROOKLYN', 'PREM_TYP_DESC': 'RESIDENCE - APT. HOUSE', 'LOC_OF_OCCUR_DESC': 'INSIDE', 'SUSP_AGE_GROUP': '25-44', 'SUSP_RACE': 'BLACK', 'SUSP_SEX': 'M', 'VIC_AGE_GROUP': '<18', 'VIC_RACE': 'BLACK', 'VIC_SEX': 'F'}
# {'_id': ObjectId('5fc69ff4d841acf8ef95ae12'), 'CMPLNT_NUM': 298673112, 'RPT_DT': '2020-06-25', 'CMPLNT_FR_DT': '2019-12-01', 'CMPLNT_TO_DT': '2019-01-12', 'CMPLNT_FR_TM': '22:00:00', 'CMPLNT_TO_TM': '22:30:00', 'JURIS_DESC': 'N.Y. POLICE DEPT', 'OFFENSE_CLASS_CODE': 104, 'LAW_CAT_CD': 'FELONY', 'OFNS_DESC': 'RAPE', 'BORO_NM': 'QUEENS', 'PREM_TYP_DESC': 'RESIDENCE-HOUSE', 'LOC_OF_OCCUR_DESC': 'INSIDE', 'SUSP_AGE_GROUP': '25-44', 'SUSP_RACE': 'WHITE HISPANIC', 'SUSP_SEX': 'M', 'VIC_AGE_GROUP': '<18', 'VIC_RACE': 'WHITE HISPANIC', 'VIC_SEX': 'F'}
# {'_id': ObjectId('5fc69ff4d841acf8ef95ae5c'), 'CMPLNT_NUM': 605057018, 'RPT_DT': '2020-06-24', 'CMPLNT_FR_DT': '2016-08-01', 'CMPLNT_TO_DT': '2020-01-05', 'CMPLNT_FR_TM': '00:01:00', 'CMPLNT_TO_TM': '00:01:00', 'JURIS_DESC': 'N.Y. POLICE DEPT', 'OFFENSE_CLASS_CODE': 116, 'LAW_CAT_CD': 'FELONY', 'OFNS_DESC': 'SEX CRIMES', 'BORO_NM': 'QUEENS', 'PREM_TYP_DESC': 'RESIDENCE - APT. HOUSE', 'LOC_OF_OCCUR_DESC': 'INSIDE', 'SUSP_AGE_GROUP': '25-44', 'SUSP_RACE': 'WHITE HISPANIC', 'SUSP_SEX': 'M', 'VIC_AGE_GROUP': '<18', 'VIC_RACE': 'WHITE HISPANIC', 'VIC_SEX': 'F'}
# {'_id': ObjectId('5fc69ff4d841acf8ef95ae5e'), 'CMPLNT_NUM': 389292195, 'RPT_DT': '2020-06-30', 'CMPLNT_FR_DT': '2020-06-30', 'CMPLNT_TO_DT': '2020-06-30', 'CMPLNT_FR_TM': '17:10:00', 'CMPLNT_TO_TM': '17:20:00', 'JURIS_DESC': 'N.Y. POLICE DEPT', 'OFFENSE_CLASS_CODE': 578, 'LAW_CAT_CD': 'VIOLATION', 'OFNS_DESC': 'HARRASSMENT 2', 'BORO_NM': 'QUEENS', 'PREM_TYP_DESC': 'RESIDENCE-HOUSE', 'LOC_OF_OCCUR_DESC': 'INSIDE', 'SUSP_AGE_GROUP': '25-44', 'SUSP_RACE': 'WHITE HISPANIC', 'SUSP_SEX': 'M', 'VIC_AGE_GROUP': '<18', 'VIC_RACE': 'WHITE HISPANIC', 'VIC_SEX': 'F'}
# {'_id': ObjectId('5fc69ff4d841acf8ef95ae61'), 'CMPLNT_NUM': 518008448, 'RPT_DT': '2020-06-24', 'CMPLNT_FR_DT': '2018-01-01', 'CMPLNT_TO_DT': '2020-01-01', 'CMPLNT_FR_TM': '00:01:00', 'CMPLNT_TO_TM': '00:01:00', 'JURIS_DESC': 'N.Y. POLICE DEPT', 'OFFENSE_CLASS_CODE': 116, 'LAW_CAT_CD': 'FELONY', 'OFNS_DESC': 'SEX CRIMES', 'BORO_NM': 'QUEENS', 'PREM_TYP_DESC': 'RESIDENCE - APT. HOUSE', 'LOC_OF_OCCUR_DESC': 'INSIDE', 'SUSP_AGE_GROUP': '25-44', 'SUSP_RACE': 'WHITE HISPANIC', 'SUSP_SEX': 'M', 'VIC_AGE_GROUP': '<18', 'VIC_RACE': 'WHITE HISPANIC', 'VIC_SEX': 'F'}
# {'_id': ObjectId('5fc69ff4d841acf8ef95ae65'), 'CMPLNT_NUM': 105183135, 'RPT_DT': '2020-06-23', 'CMPLNT_FR_DT': '2020-06-22', 'CMPLNT_TO_DT': '2020-06-22', 'CMPLNT_FR_TM': '23:30:00', 'CMPLNT_TO_TM': '23:45:00', 'JURIS_DESC': 'N.Y. HOUSING POLICE', 'OFFENSE_CLASS_CODE': 578, 'LAW_CAT_CD': 'VIOLATION', 'OFNS_DESC': 'HARRASSMENT 2', 'BORO_NM': 'BROOKLYN', 'PREM_TYP_DESC': 'RESIDENCE - PUBLIC HOUSING', 'LOC_OF_OCCUR_DESC': 'INSIDE', 'SUSP_AGE_GROUP': '18-24', 'SUSP_RACE': 'BLACK', 'SUSP_SEX': 'M', 'VIC_AGE_GROUP': '<18', 'VIC_RACE': 'BLACK', 'VIC_SEX': 'F'}
# {'_id': ObjectId('5fc69ff4d841acf8ef95ae72'), 'CMPLNT_NUM': 113769473, 'RPT_DT': '2020-06-30', 'CMPLNT_FR_DT': '2020-06-30', 'CMPLNT_TO_DT': '2020-06-30', 'CMPLNT_FR_TM': '21:10:00', 'CMPLNT_TO_TM': '21:15:00', 'JURIS_DESC': 'N.Y. POLICE DEPT', 'OFFENSE_CLASS_CODE': 578, 'LAW_CAT_CD': 'VIOLATION', 'OFNS_DESC': 'HARRASSMENT 2', 'BORO_NM': 'QUEENS', 'PREM_TYP_DESC': 'RESIDENCE-HOUSE', 'LOC_OF_OCCUR_DESC': 'INSIDE', 'SUSP_AGE_GROUP': '18-24', 'SUSP_RACE': 'BLACK', 'SUSP_SEX': 'M', 'VIC_AGE_GROUP': '<18', 'VIC_RACE': 'BLACK', 'VIC_SEX': 'F'}
# {'_id': ObjectId('5fc69ff4d841acf8ef95ae81'), 'CMPLNT_NUM': 442409142, 'RPT_DT': '2020-06-22', 'CMPLNT_FR_DT': '2017-09-09', 'CMPLNT_TO_DT': '2020-06-22', 'CMPLNT_FR_TM': '13:00:00', 'CMPLNT_TO_TM': '10:30:00', 'JURIS_DESC': 'N.Y. POLICE DEPT', 'OFFENSE_CLASS_CODE': 361, 'LAW_CAT_CD': 'MISDEMEANOR', 'OFNS_DESC': 'OFF. AGNST PUB ORD SENSBLTY &', 'BORO_NM': 'MANHATTAN', 'PREM_TYP_DESC': 'PUBLIC SCHOOL', 'LOC_OF_OCCUR_DESC': 'INSIDE', 'SUSP_AGE_GROUP': '18-24', 'SUSP_RACE': 'ASIAN / PACIFIC ISLANDER', 'SUSP_SEX': 'M', 'VIC_AGE_GROUP': '<18', 'VIC_RACE': 'WHITE', 'VIC_SEX': 'F'}
# {'_id': ObjectId('5fc69ff4d841acf8ef95ae86'), 'CMPLNT_NUM': 216006425, 'RPT_DT': '2020-06-22', 'CMPLNT_FR_DT': '2019-01-01', 'CMPLNT_TO_DT': '2019-02-01', 'CMPLNT_FR_TM': '15:00:00', 'CMPLNT_TO_TM': '15:00:00', 'JURIS_DESC': 'N.Y. HOUSING POLICE', 'OFFENSE_CLASS_CODE': 578, 'LAW_CAT_CD': 'VIOLATION', 'OFNS_DESC': 'HARRASSMENT 2', 'BORO_NM': 'BROOKLYN', 'PREM_TYP_DESC': 'RESIDENCE - PUBLIC HOUSING', 'LOC_OF_OCCUR_DESC': 'INSIDE', 'SUSP_AGE_GROUP': 'UNKNOWN', 'SUSP_RACE': 'BLACK', 'SUSP_SEX': 'U', 'VIC_AGE_GROUP': '<18', 'VIC_RACE': 'BLACK', 'VIC_SEX': 'F'}
# {'_id': ObjectId('5fc69ff4d841acf8ef95aeb3'), 'CMPLNT_NUM': 274795202, 'RPT_DT': '2020-06-22', 'CMPLNT_FR_DT': '2020-06-20', 'CMPLNT_TO_DT': '2020-06-21', 'CMPLNT_FR_TM': '08:00:00', 'CMPLNT_TO_TM': '22:00:00', 'JURIS_DESC': 'N.Y. POLICE DEPT', 'OFFENSE_CLASS_CODE': 233, 'LAW_CAT_CD': 'MISDEMEANOR', 'OFNS_DESC': 'SEX CRIMES', 'BORO_NM': 'QUEENS', 'PREM_TYP_DESC': 'RESIDENCE-HOUSE', 'LOC_OF_OCCUR_DESC': 'INSIDE', 'SUSP_AGE_GROUP': '25-44', 'SUSP_RACE': 'WHITE HISPANIC', 'SUSP_SEX': 'M', 'VIC_AGE_GROUP': '<18', 'VIC_RACE': 'WHITE', 'VIC_SEX': 'F'}
# {'_id': ObjectId('5fc69ff4d841acf8ef95aee0'), 'CMPLNT_NUM': 958686403, 'RPT_DT': '2020-06-24', 'CMPLNT_FR_DT': '2020-06-22', 'CMPLNT_TO_DT': '2020-06-22', 'CMPLNT_FR_TM': '18:30:00', 'CMPLNT_TO_TM': '18:40:00', 'JURIS_DESC': 'N.Y. HOUSING POLICE', 'OFFENSE_CLASS_CODE': 104, 'LAW_CAT_CD': 'FELONY', 'OFNS_DESC': 'RAPE', 'BORO_NM': 'BRONX', 'PREM_TYP_DESC': 'RESIDENCE - PUBLIC HOUSING', 'LOC_OF_OCCUR_DESC': 'INSIDE', 'SUSP_AGE_GROUP': '18-24', 'SUSP_RACE': 'BLACK', 'SUSP_SEX': 'M', 'VIC_AGE_GROUP': '<18', 'VIC_RACE': 'BLACK', 'VIC_SEX': 'F'}
# {'_id': ObjectId('5fc69ff4d841acf8ef95aef0'), 'CMPLNT_NUM': 374022412, 'RPT_DT': '2020-06-24', 'CMPLNT_FR_DT': '2016-06-24', 'CMPLNT_TO_DT': '2020-06-24', 'CMPLNT_FR_TM': '12:00:00', 'CMPLNT_TO_TM': '00:00:00', 'JURIS_DESC': 'N.Y. POLICE DEPT', 'OFFENSE_CLASS_CODE': 116, 'LAW_CAT_CD': 'FELONY', 'OFNS_DESC': 'SEX CRIMES', 'BORO_NM': 'QUEENS', 'PREM_TYP_DESC': 'RESIDENCE-HOUSE', 'LOC_OF_OCCUR_DESC': 'INSIDE', 'SUSP_AGE_GROUP': '45-64', 'SUSP_RACE': 'ASIAN / PACIFIC ISLANDER', 'SUSP_SEX': 'M', 'VIC_AGE_GROUP': '<18', 'VIC_RACE': 'ASIAN / PACIFIC ISLANDER', 'VIC_SEX': 'F'}
# {'_id': ObjectId('5fc69ff4d841acf8ef95aef2'), 'CMPLNT_NUM': 155051450, 'RPT_DT': '2020-06-25', 'CMPLNT_FR_DT': '2020-06-25', 'CMPLNT_TO_DT': '2020-06-25', 'CMPLNT_FR_TM': '15:00:00', 'CMPLNT_TO_TM': '16:15:00', 'JURIS_DESC': 'N.Y. POLICE DEPT', 'OFFENSE_CLASS_CODE': 344, 'LAW_CAT_CD': 'MISDEMEANOR', 'OFNS_DESC': 'ASSAULT 3 & RELATED OFFENSES', 'BORO_NM': 'QUEENS', 'PREM_TYP_DESC': 'RESIDENCE-HOUSE', 'LOC_OF_OCCUR_DESC': 'INSIDE', 'SUSP_AGE_GROUP': '18-24', 'SUSP_RACE': 'WHITE', 'SUSP_SEX': 'M', 'VIC_AGE_GROUP': '<18', 'VIC_RACE': 'WHITE HISPANIC', 'VIC_SEX': 'F'}
# {'_id': ObjectId('5fc69ff4d841acf8ef95aeff'), 'CMPLNT_NUM': 299717660, 'RPT_DT': '2020-06-24', 'CMPLNT_FR_DT': '2020-06-23', 'CMPLNT_TO_DT': '2020-06-23', 'CMPLNT_FR_TM': '14:00:00', 'CMPLNT_TO_TM': '22:00:00', 'JURIS_DESC': 'N.Y. POLICE DEPT', 'OFFENSE_CLASS_CODE': 578, 'LAW_CAT_CD': 'VIOLATION', 'OFNS_DESC': 'HARRASSMENT 2', 'BORO_NM': 'BROOKLYN', 'PREM_TYP_DESC': 'RESIDENCE-HOUSE', 'LOC_OF_OCCUR_DESC': 'FRONT OF', 'SUSP_AGE_GROUP': '<18', 'SUSP_RACE': 'BLACK HISPANIC', 'SUSP_SEX': 'M', 'VIC_AGE_GROUP': '<18', 'VIC_RACE': 'BLACK', 'VIC_SEX': 'F'}
# {'_id': ObjectId('5fc69ff4d841acf8ef95af65'), 'CMPLNT_NUM': 282718195, 'RPT_DT': '2020-06-23', 'CMPLNT_FR_DT': '2020-06-23', 'CMPLNT_TO_DT': '2020-06-23', 'CMPLNT_FR_TM': '14:00:00', 'CMPLNT_TO_TM': '15:30:00', 'JURIS_DESC': 'N.Y. POLICE DEPT', 'OFFENSE_CLASS_CODE': 233, 'LAW_CAT_CD': 'MISDEMEANOR', 'OFNS_DESC': 'SEX CRIMES', 'BORO_NM': 'STATEN ISLAND', 'PREM_TYP_DESC': 'RESIDENCE - APT. HOUSE', 'LOC_OF_OCCUR_DESC': 'INSIDE', 'SUSP_AGE_GROUP': 'UNKNOWN', 'SUSP_RACE': 'UNKNOWN', 'SUSP_SEX': 'U', 'VIC_AGE_GROUP': '<18', 'VIC_RACE': 'WHITE', 'VIC_SEX': 'F'}
# {'_id': ObjectId('5fc69ff4d841acf8ef95af91'), 'CMPLNT_NUM': 808834918, 'RPT_DT': '2020-06-26', 'CMPLNT_FR_DT': '2020-06-26', 'CMPLNT_TO_DT': '2020-06-26', 'CMPLNT_FR_TM': '20:20:00', 'CMPLNT_TO_TM': '20:40:00', 'JURIS_DESC': 'N.Y. POLICE DEPT', 'OFFENSE_CLASS_CODE': 344, 'LAW_CAT_CD': 'MISDEMEANOR', 'OFNS_DESC': 'ASSAULT 3 & RELATED OFFENSES', 'BORO_NM': 'QUEENS', 'PREM_TYP_DESC': 'CHAIN STORE', 'LOC_OF_OCCUR_DESC': 'INSIDE', 'SUSP_AGE_GROUP': '<18', 'SUSP_RACE': 'BLACK', 'SUSP_SEX': 'F', 'VIC_AGE_GROUP': '<18', 'VIC_RACE': 'BLACK', 'VIC_SEX': 'F'}
# {'_id': ObjectId('5fc69ff4d841acf8ef95afb5'), 'CMPLNT_NUM': 455862724, 'RPT_DT': '2020-06-24', 'CMPLNT_FR_DT': '2020-06-24', 'CMPLNT_TO_DT': '2020-06-24', 'CMPLNT_FR_TM': '00:12:00', 'CMPLNT_TO_TM': '00:25:00', 'JURIS_DESC': 'N.Y. HOUSING POLICE', 'OFFENSE_CLASS_CODE': 105, 'LAW_CAT_CD': 'FELONY', 'OFNS_DESC': 'ROBBERY', 'BORO_NM': 'BROOKLYN', 'PREM_TYP_DESC': 'RESIDENCE - PUBLIC HOUSING', 'LOC_OF_OCCUR_DESC': 'FRONT OF', 'SUSP_AGE_GROUP': 'UNKNOWN', 'SUSP_RACE': 'UNKNOWN', 'SUSP_SEX': 'U', 'VIC_AGE_GROUP': '<18', 'VIC_RACE': 'WHITE HISPANIC', 'VIC_SEX': 'F'}
# {'_id': ObjectId('5fc69ff4d841acf8ef95afd6'), 'CMPLNT_NUM': 147262121, 'RPT_DT': '2020-06-28', 'CMPLNT_FR_DT': '2020-05-16', 'CMPLNT_TO_DT': '2020-06-27', 'CMPLNT_FR_TM': '00:09:00', 'CMPLNT_TO_TM': '21:20:00', 'JURIS_DESC': 'N.Y. POLICE DEPT', 'OFFENSE_CLASS_CODE': 361, 'LAW_CAT_CD': 'MISDEMEANOR', 'OFNS_DESC': 'OFF. AGNST PUB ORD SENSBLTY &', 'BORO_NM': 'QUEENS', 'PREM_TYP_DESC': 'RESIDENCE-HOUSE', 'LOC_OF_OCCUR_DESC': 'INSIDE', 'SUSP_AGE_GROUP': '25-44', 'SUSP_RACE': 'ASIAN / PACIFIC ISLANDER', 'SUSP_SEX': 'M', 'VIC_AGE_GROUP': '<18', 'VIC_RACE': 'ASIAN / PACIFIC ISLANDER', 'VIC_SEX': 'F'}
# {'_id': ObjectId('5fc69ff4d841acf8ef95affa'), 'CMPLNT_NUM': 358890423, 'RPT_DT': '2020-06-29', 'CMPLNT_FR_DT': '2020-06-28', 'CMPLNT_TO_DT': '2020-06-28', 'CMPLNT_FR_TM': '21:22:00', 'CMPLNT_TO_TM': '21:27:00', 'JURIS_DESC': 'N.Y. HOUSING POLICE', 'OFFENSE_CLASS_CODE': 233, 'LAW_CAT_CD': 'MISDEMEANOR', 'OFNS_DESC': 'SEX CRIMES', 'BORO_NM': 'BRONX', 'PREM_TYP_DESC': 'RESIDENCE - PUBLIC HOUSING', 'LOC_OF_OCCUR_DESC': 'INSIDE', 'SUSP_AGE_GROUP': 'UNKNOWN', 'SUSP_RACE': 'BLACK', 'SUSP_SEX': 'M', 'VIC_AGE_GROUP': '<18', 'VIC_RACE': 'WHITE HISPANIC', 'VIC_SEX': 'F'}
# {'_id': ObjectId('5fc69ff4d841acf8ef95b05e'), 'CMPLNT_NUM': 433914551, 'RPT_DT': '2020-06-25', 'CMPLNT_FR_DT': '2020-06-25', 'CMPLNT_TO_DT': '2020-06-25', 'CMPLNT_FR_TM': '03:20:00', 'CMPLNT_TO_TM': '03:30:00', 'JURIS_DESC': 'N.Y. POLICE DEPT', 'OFFENSE_CLASS_CODE': 105, 'LAW_CAT_CD': 'FELONY', 'OFNS_DESC': 'ROBBERY', 'BORO_NM': 'BROOKLYN', 'PREM_TYP_DESC': 'STREET', 'LOC_OF_OCCUR_DESC': 'FRONT OF', 'SUSP_AGE_GROUP': 'UNKNOWN', 'SUSP_RACE': 'UNKNOWN', 'SUSP_SEX': 'U', 'VIC_AGE_GROUP': '<18', 'VIC_RACE': 'BLACK HISPANIC', 'VIC_SEX': 'F'}
# {'_id': ObjectId('5fc69ff4d841acf8ef95b139'), 'CMPLNT_NUM': 681006770, 'RPT_DT': '2020-06-29', 'CMPLNT_FR_DT': '2020-06-23', 'CMPLNT_TO_DT': '2020-06-23', 'CMPLNT_FR_TM': '23:00:00', 'CMPLNT_TO_TM': '23:35:00', 'JURIS_DESC': 'N.Y. HOUSING POLICE', 'OFFENSE_CLASS_CODE': 578, 'LAW_CAT_CD': 'VIOLATION', 'OFNS_DESC': 'HARRASSMENT 2', 'BORO_NM': 'BROOKLYN', 'PREM_TYP_DESC': 'RESIDENCE - PUBLIC HOUSING', 'LOC_OF_OCCUR_DESC': 'INSIDE', 'SUSP_AGE_GROUP': '45-64', 'SUSP_RACE': 'BLACK', 'SUSP_SEX': 'F', 'VIC_AGE_GROUP': '<18', 'VIC_RACE': 'BLACK', 'VIC_SEX': 'F'}
# {'_id': ObjectId('5fc69ff4d841acf8ef95b1ef'), 'CMPLNT_NUM': 934732906, 'RPT_DT': '2020-06-28', 'CMPLNT_FR_DT': '2020-06-04', 'CMPLNT_TO_DT': '2020-06-25', 'CMPLNT_FR_TM': '13:00:00', 'CMPLNT_TO_TM': '18:13:00', 'JURIS_DESC': 'N.Y. POLICE DEPT', 'OFFENSE_CLASS_CODE': 109, 'LAW_CAT_CD': 'FELONY', 'OFNS_DESC': 'GRAND LARCENY', 'BORO_NM': 'MANHATTAN', 'PREM_TYP_DESC': 'RESIDENCE - APT. HOUSE', 'LOC_OF_OCCUR_DESC': 'INSIDE', 'SUSP_AGE_GROUP': 'UNKNOWN', 'SUSP_RACE': 'UNKNOWN', 'SUSP_SEX': 'U', 'VIC_AGE_GROUP': '<18', 'VIC_RACE': 'WHITE', 'VIC_SEX': 'F'}
# {'_id': ObjectId('5fc69ff4d841acf8ef95b257'), 'CMPLNT_NUM': 439223141, 'RPT_DT': '2020-06-28', 'CMPLNT_FR_DT': '2020-06-26', 'CMPLNT_TO_DT': '2020-06-28', 'CMPLNT_FR_TM': '00:01:00', 'CMPLNT_TO_TM': '15:00:00', 'JURIS_DESC': 'N.Y. POLICE DEPT', 'OFFENSE_CLASS_CODE': 578, 'LAW_CAT_CD': 'VIOLATION', 'OFNS_DESC': 'HARRASSMENT 2', 'BORO_NM': 'QUEENS', 'PREM_TYP_DESC': 'RESIDENCE-HOUSE', 'LOC_OF_OCCUR_DESC': 'INSIDE', 'SUSP_AGE_GROUP': '<18', 'SUSP_RACE': 'UNKNOWN', 'SUSP_SEX': 'M', 'VIC_AGE_GROUP': '<18', 'VIC_RACE': 'ASIAN / PACIFIC ISLANDER', 'VIC_SEX': 'F'}
# {'_id': ObjectId('5fc69ff4d841acf8ef95b2cd'), 'CMPLNT_NUM': 236311531, 'RPT_DT': '2020-06-30', 'CMPLNT_FR_DT': '2020-06-30', 'CMPLNT_TO_DT': '2020-06-30', 'CMPLNT_FR_TM': '13:45:00', 'CMPLNT_TO_TM': '15:30:00', 'JURIS_DESC': 'N.Y. POLICE DEPT', 'OFFENSE_CLASS_CODE': 233, 'LAW_CAT_CD': 'MISDEMEANOR', 'OFNS_DESC': 'SEX CRIMES', 'BORO_NM': 'BRONX', 'PREM_TYP_DESC': 'PARK/PLAYGROUND', 'LOC_OF_OCCUR_DESC': 'OPPOSITE OF', 'SUSP_AGE_GROUP': '25-44', 'SUSP_RACE': 'WHITE HISPANIC', 'SUSP_SEX': 'M', 'VIC_AGE_GROUP': '<18', 'VIC_RACE': 'WHITE HISPANIC', 'VIC_SEX': 'F'}
# {'_id': ObjectId('5fc69ff4d841acf8ef95b305'), 'CMPLNT_NUM': 259161917, 'RPT_DT': '2020-06-26', 'CMPLNT_FR_DT': '2020-06-26', 'CMPLNT_TO_DT': '2020-06-26', 'CMPLNT_FR_TM': '13:30:00', 'CMPLNT_TO_TM': '13:35:00', 'JURIS_DESC': 'N.Y. POLICE DEPT', 'OFFENSE_CLASS_CODE': 344, 'LAW_CAT_CD': 'MISDEMEANOR', 'OFNS_DESC': 'ASSAULT 3 & RELATED OFFENSES', 'BORO_NM': 'QUEENS', 'PREM_TYP_DESC': 'RESIDENCE - APT. HOUSE', 'LOC_OF_OCCUR_DESC': 'INSIDE', 'SUSP_AGE_GROUP': '25-44', 'SUSP_RACE': 'ASIAN / PACIFIC ISLANDER', 'SUSP_SEX': 'M', 'VIC_AGE_GROUP': '<18', 'VIC_RACE': 'ASIAN / PACIFIC ISLANDER', 'VIC_SEX': 'F'}
# {'_id': ObjectId('5fc69ff4d841acf8ef95b32a'), 'CMPLNT_NUM': 159379155, 'RPT_DT': '2020-06-28', 'CMPLNT_FR_DT': '2020-06-28', 'CMPLNT_TO_DT': '2020-06-28', 'CMPLNT_FR_TM': '13:30:00', 'CMPLNT_TO_TM': '14:00:00', 'JURIS_DESC': 'N.Y. POLICE DEPT', 'OFFENSE_CLASS_CODE': 578, 'LAW_CAT_CD': 'VIOLATION', 'OFNS_DESC': 'HARRASSMENT 2', 'BORO_NM': 'STATEN ISLAND', 'PREM_TYP_DESC': 'RESIDENCE-HOUSE', 'LOC_OF_OCCUR_DESC': 'INSIDE', 'SUSP_AGE_GROUP': '45-64', 'SUSP_RACE': 'UNKNOWN', 'SUSP_SEX': 'F', 'VIC_AGE_GROUP': '<18', 'VIC_RACE': 'WHITE', 'VIC_SEX': 'F'}
# {'_id': ObjectId('5fc69ff4d841acf8ef95b34c'), 'CMPLNT_NUM': 736567200, 'RPT_DT': '2020-06-28', 'CMPLNT_FR_DT': '2020-06-24', 'CMPLNT_TO_DT': '2020-06-24', 'CMPLNT_FR_TM': '12:20:00', 'CMPLNT_TO_TM': '12:30:00', 'JURIS_DESC': 'N.Y. POLICE DEPT', 'OFFENSE_CLASS_CODE': 344, 'LAW_CAT_CD': 'MISDEMEANOR', 'OFNS_DESC': 'ASSAULT 3 & RELATED OFFENSES', 'BORO_NM': 'MANHATTAN', 'PREM_TYP_DESC': 'PARK/PLAYGROUND', 'LOC_OF_OCCUR_DESC': 'INSIDE', 'SUSP_AGE_GROUP': '18-24', 'SUSP_RACE': 'BLACK', 'SUSP_SEX': 'M', 'VIC_AGE_GROUP': '<18', 'VIC_RACE': 'BLACK', 'VIC_SEX': 'F'}
# {'_id': ObjectId('5fc69ff4d841acf8ef95b368'), 'CMPLNT_NUM': 660076333, 'RPT_DT': '2020-06-23', 'CMPLNT_FR_DT': '2020-06-23', 'CMPLNT_TO_DT': '2020-06-23', 'CMPLNT_FR_TM': '14:25:00', 'CMPLNT_TO_TM': '14:35:00', 'JURIS_DESC': 'N.Y. POLICE DEPT', 'OFFENSE_CLASS_CODE': 233, 'LAW_CAT_CD': 'MISDEMEANOR', 'OFNS_DESC': 'SEX CRIMES', 'BORO_NM': 'QUEENS', 'PREM_TYP_DESC': 'RESIDENCE-HOUSE', 'LOC_OF_OCCUR_DESC': 'INSIDE', 'SUSP_AGE_GROUP': '45-64', 'SUSP_RACE': 'ASIAN / PACIFIC ISLANDER', 'SUSP_SEX': 'M', 'VIC_AGE_GROUP': '<18', 'VIC_RACE': 'ASIAN / PACIFIC ISLANDER', 'VIC_SEX': 'F'}
# {'_id': ObjectId('5fc69ff4d841acf8ef95b3b8'), 'CMPLNT_NUM': 674329210, 'RPT_DT': '2020-06-26', 'CMPLNT_FR_DT': '2020-06-17', 'CMPLNT_TO_DT': '2020-06-17', 'CMPLNT_FR_TM': '00:00:00', 'CMPLNT_TO_TM': '23:59:00', 'JURIS_DESC': 'N.Y. POLICE DEPT', 'OFFENSE_CLASS_CODE': 233, 'LAW_CAT_CD': 'MISDEMEANOR', 'OFNS_DESC': 'SEX CRIMES', 'BORO_NM': 'BROOKLYN', 'PREM_TYP_DESC': 'RESIDENCE - APT. HOUSE', 'LOC_OF_OCCUR_DESC': 'INSIDE', 'SUSP_AGE_GROUP': 'UNKNOWN', 'SUSP_RACE': 'UNKNOWN', 'SUSP_SEX': 'M', 'VIC_AGE_GROUP': '<18', 'VIC_RACE': 'BLACK', 'VIC_SEX': 'F'}
# {'_id': ObjectId('5fc69ff4d841acf8ef95b3cb'), 'CMPLNT_NUM': 585101823, 'RPT_DT': '2020-06-29', 'CMPLNT_FR_DT': '2020-06-29', 'CMPLNT_TO_DT': '2020-06-29', 'CMPLNT_FR_TM': '11:35:00', 'CMPLNT_TO_TM': '11:38:00', 'JURIS_DESC': 'N.Y. POLICE DEPT', 'OFFENSE_CLASS_CODE': 233, 'LAW_CAT_CD': 'MISDEMEANOR', 'OFNS_DESC': 'SEX CRIMES', 'BORO_NM': 'QUEENS', 'PREM_TYP_DESC': 'RESIDENCE-HOUSE', 'LOC_OF_OCCUR_DESC': 'INSIDE', 'SUSP_AGE_GROUP': '25-44', 'SUSP_RACE': 'WHITE HISPANIC', 'SUSP_SEX': 'M', 'VIC_AGE_GROUP': '<18', 'VIC_RACE': 'WHITE HISPANIC', 'VIC_SEX': 'F'}
# {'_id': ObjectId('5fc69ff4d841acf8ef95b3d6'), 'CMPLNT_NUM': 522224532, 'RPT_DT': '2020-06-25', 'CMPLNT_FR_DT': '2017-06-01', 'CMPLNT_TO_DT': '2020-06-16', 'CMPLNT_FR_TM': '00:01:00', 'CMPLNT_TO_TM': '23:59:00', 'JURIS_DESC': 'N.Y. POLICE DEPT', 'OFFENSE_CLASS_CODE': 104, 'LAW_CAT_CD': 'FELONY', 'OFNS_DESC': 'RAPE', 'BORO_NM': 'BROOKLYN', 'PREM_TYP_DESC': 'RESIDENCE - APT. HOUSE', 'LOC_OF_OCCUR_DESC': 'INSIDE', 'SUSP_AGE_GROUP': 'UNKNOWN', 'SUSP_RACE': 'UNKNOWN', 'SUSP_SEX': 'M', 'VIC_AGE_GROUP': '<18', 'VIC_RACE': 'BLACK', 'VIC_SEX': 'F'}
# {'_id': ObjectId('5fc69ff4d841acf8ef95b3f8'), 'CMPLNT_NUM': 163182814, 'RPT_DT': '2020-06-29', 'CMPLNT_FR_DT': '2020-06-14', 'CMPLNT_TO_DT': '2020-06-14', 'CMPLNT_FR_TM': '00:01:00', 'CMPLNT_TO_TM': '02:00:00', 'JURIS_DESC': 'N.Y. POLICE DEPT', 'OFFENSE_CLASS_CODE': 116, 'LAW_CAT_CD': 'FELONY', 'OFNS_DESC': 'SEX CRIMES', 'BORO_NM': 'BROOKLYN', 'PREM_TYP_DESC': 'RESIDENCE - APT. HOUSE', 'LOC_OF_OCCUR_DESC': 'INSIDE', 'SUSP_AGE_GROUP': '25-44', 'SUSP_RACE': 'WHITE HISPANIC', 'SUSP_SEX': 'M', 'VIC_AGE_GROUP': '<18', 'VIC_RACE': 'BLACK HISPANIC', 'VIC_SEX': 'F'}
# {'_id': ObjectId('5fc69ff4d841acf8ef95b408'), 'CMPLNT_NUM': 979267372, 'RPT_DT': '2020-06-25', 'CMPLNT_FR_DT': '2020-06-24', 'CMPLNT_TO_DT': '2020-06-25', 'CMPLNT_FR_TM': '23:30:00', 'CMPLNT_TO_TM': '00:00:00', 'JURIS_DESC': 'N.Y. POLICE DEPT', 'OFFENSE_CLASS_CODE': 233, 'LAW_CAT_CD': 'MISDEMEANOR', 'OFNS_DESC': 'SEX CRIMES', 'BORO_NM': 'QUEENS', 'PREM_TYP_DESC': 'PARK/PLAYGROUND', 'LOC_OF_OCCUR_DESC': 'INSIDE', 'SUSP_AGE_GROUP': '25-44', 'SUSP_RACE': 'WHITE HISPANIC', 'SUSP_SEX': 'M', 'VIC_AGE_GROUP': '<18', 'VIC_RACE': 'BLACK HISPANIC', 'VIC_SEX': 'F'}
# {'_id': ObjectId('5fc69ff4d841acf8ef95b41b'), 'CMPLNT_NUM': 847725555, 'RPT_DT': '2020-06-30', 'CMPLNT_FR_DT': '2020-06-30', 'CMPLNT_TO_DT': '2020-06-30', 'CMPLNT_FR_TM': '13:40:00', 'CMPLNT_TO_TM': '13:45:00', 'JURIS_DESC': 'N.Y. POLICE DEPT', 'OFFENSE_CLASS_CODE': 578, 'LAW_CAT_CD': 'VIOLATION', 'OFNS_DESC': 'HARRASSMENT 2', 'BORO_NM': 'QUEENS', 'PREM_TYP_DESC': 'CHAIN STORE', 'LOC_OF_OCCUR_DESC': 'FRONT OF', 'SUSP_AGE_GROUP': '45-64', 'SUSP_RACE': 'UNKNOWN', 'SUSP_SEX': 'F', 'VIC_AGE_GROUP': '<18', 'VIC_RACE': 'ASIAN / PACIFIC ISLANDER', 'VIC_SEX': 'F'}
# {'_id': ObjectId('5fc69ff4d841acf8ef95b50e'), 'CMPLNT_NUM': 832433226, 'RPT_DT': '2020-06-30', 'CMPLNT_FR_DT': '2020-06-30', 'CMPLNT_TO_DT': '2020-06-30', 'CMPLNT_FR_TM': '00:10:00', 'CMPLNT_TO_TM': '00:10:00', 'JURIS_DESC': 'N.Y. POLICE DEPT', 'OFFENSE_CLASS_CODE': 126, 'LAW_CAT_CD': 'FELONY', 'OFNS_DESC': 'MISCELLANEOUS PENAL LAW', 'BORO_NM': 'QUEENS', 'PREM_TYP_DESC': 'RESIDENCE-HOUSE', 'LOC_OF_OCCUR_DESC': 'INSIDE', 'SUSP_AGE_GROUP': '18-24', 'SUSP_RACE': 'WHITE HISPANIC', 'SUSP_SEX': 'M', 'VIC_AGE_GROUP': '<18', 'VIC_RACE': 'WHITE HISPANIC', 'VIC_SEX': 'F'}
# {'_id': ObjectId('5fc69ff4d841acf8ef95b59e'), 'CMPLNT_NUM': 870984563, 'RPT_DT': '2020-06-26', 'CMPLNT_FR_DT': '2020-06-26', 'CMPLNT_TO_DT': '2020-06-26', 'CMPLNT_FR_TM': '07:05:00', 'CMPLNT_TO_TM': '07:40:00', 'JURIS_DESC': 'N.Y. POLICE DEPT', 'OFFENSE_CLASS_CODE': 105, 'LAW_CAT_CD': 'FELONY', 'OFNS_DESC': 'ROBBERY', 'BORO_NM': 'BRONX', 'PREM_TYP_DESC': 'STREET', 'LOC_OF_OCCUR_DESC': 'FRONT OF', 'SUSP_AGE_GROUP': 'UNKNOWN', 'SUSP_RACE': 'BLACK HISPANIC', 'SUSP_SEX': 'M', 'VIC_AGE_GROUP': '<18', 'VIC_RACE': 'BLACK HISPANIC', 'VIC_SEX': 'F'}
# {'_id': ObjectId('5fc69ff4d841acf8ef95b5d4'), 'CMPLNT_NUM': 353971174, 'RPT_DT': '2020-06-27', 'CMPLNT_FR_DT': '2020-06-27', 'CMPLNT_TO_DT': '2020-06-27', 'CMPLNT_FR_TM': '18:50:00', 'CMPLNT_TO_TM': '19:10:00', 'JURIS_DESC': 'N.Y. POLICE DEPT', 'OFFENSE_CLASS_CODE': 106, 'LAW_CAT_CD': 'FELONY', 'OFNS_DESC': 'FELONY ASSAULT', 'BORO_NM': 'BRONX', 'PREM_TYP_DESC': 'RESIDENCE - APT. HOUSE', 'LOC_OF_OCCUR_DESC': 'FRONT OF', 'SUSP_AGE_GROUP': '25-44', 'SUSP_RACE': 'BLACK HISPANIC', 'SUSP_SEX': 'M', 'VIC_AGE_GROUP': '<18', 'VIC_RACE': 'BLACK HISPANIC', 'VIC_SEX': 'F'}
# {'_id': ObjectId('5fc69ff4d841acf8ef95b690'), 'CMPLNT_NUM': 274054226, 'RPT_DT': '2020-06-24', 'CMPLNT_FR_DT': '2020-06-24', 'CMPLNT_TO_DT': '2020-06-24', 'CMPLNT_FR_TM': '15:15:00', 'CMPLNT_TO_TM': '15:30:00', 'JURIS_DESC': 'N.Y. POLICE DEPT', 'OFFENSE_CLASS_CODE': 344, 'LAW_CAT_CD': 'MISDEMEANOR', 'OFNS_DESC': 'ASSAULT 3 & RELATED OFFENSES', 'BORO_NM': 'STATEN ISLAND', 'PREM_TYP_DESC': 'RESIDENCE-HOUSE', 'LOC_OF_OCCUR_DESC': 'INSIDE', 'SUSP_AGE_GROUP': '25-44', 'SUSP_RACE': 'BLACK', 'SUSP_SEX': 'F', 'VIC_AGE_GROUP': '<18', 'VIC_RACE': 'UNKNOWN', 'VIC_SEX': 'F'}
# {'_id': ObjectId('5fc69ff4d841acf8ef95b699'), 'CMPLNT_NUM': 651704249, 'RPT_DT': '2020-06-30', 'CMPLNT_FR_DT': '2020-06-29', 'CMPLNT_TO_DT': '2020-06-29', 'CMPLNT_FR_TM': '22:00:00', 'CMPLNT_TO_TM': '23:00:00', 'JURIS_DESC': 'N.Y. POLICE DEPT', 'OFFENSE_CLASS_CODE': 361, 'LAW_CAT_CD': 'MISDEMEANOR', 'OFNS_DESC': 'OFF. AGNST PUB ORD SENSBLTY &', 'BORO_NM': 'BROOKLYN', 'PREM_TYP_DESC': 'RESIDENCE - APT. HOUSE', 'LOC_OF_OCCUR_DESC': 'INSIDE', 'SUSP_AGE_GROUP': 'UNKNOWN', 'SUSP_RACE': 'UNKNOWN', 'SUSP_SEX': 'F', 'VIC_AGE_GROUP': '<18', 'VIC_RACE': 'UNKNOWN', 'VIC_SEX': 'F'}
# {'_id': ObjectId('5fc69ff4d841acf8ef95b6de'), 'CMPLNT_NUM': 807437781, 'RPT_DT': '2020-06-23', 'CMPLNT_FR_DT': '2014-08-01', 'CMPLNT_TO_DT': '2016-01-09', 'CMPLNT_FR_TM': '00:01:00', 'CMPLNT_TO_TM': '23:59:00', 'JURIS_DESC': 'N.Y. HOUSING POLICE', 'OFFENSE_CLASS_CODE': 116, 'LAW_CAT_CD': 'FELONY', 'OFNS_DESC': 'SEX CRIMES', 'BORO_NM': 'BROOKLYN', 'PREM_TYP_DESC': 'RESIDENCE - PUBLIC HOUSING', 'LOC_OF_OCCUR_DESC': 'INSIDE', 'SUSP_AGE_GROUP': '25-44', 'SUSP_RACE': 'BLACK', 'SUSP_SEX': 'M', 'VIC_AGE_GROUP': '<18', 'VIC_RACE': 'BLACK', 'VIC_SEX': 'F'}
# {'_id': ObjectId('5fc69ff4d841acf8ef95b6f3'), 'CMPLNT_NUM': 803357525, 'RPT_DT': '2020-06-22', 'CMPLNT_FR_DT': '2020-06-22', 'CMPLNT_TO_DT': '2020-06-22', 'CMPLNT_FR_TM': '10:25:00', 'CMPLNT_TO_TM': '11:21:00', 'JURIS_DESC': 'N.Y. POLICE DEPT', 'OFFENSE_CLASS_CODE': 344, 'LAW_CAT_CD': 'MISDEMEANOR', 'OFNS_DESC': 'ASSAULT 3 & RELATED OFFENSES', 'BORO_NM': 'QUEENS', 'PREM_TYP_DESC': 'RESIDENCE - APT. HOUSE', 'LOC_OF_OCCUR_DESC': 'INSIDE', 'SUSP_AGE_GROUP': '18-24', 'SUSP_RACE': 'WHITE HISPANIC', 'SUSP_SEX': 'F', 'VIC_AGE_GROUP': '<18', 'VIC_RACE': 'WHITE HISPANIC', 'VIC_SEX': 'F'}
# {'_id': ObjectId('5fc69ff4d841acf8ef95b742'), 'CMPLNT_NUM': 236942241, 'RPT_DT': '2020-06-29', 'CMPLNT_FR_DT': '2018-10-20', 'CMPLNT_TO_DT': '2018-10-20', 'CMPLNT_FR_TM': '09:45:00', 'CMPLNT_TO_TM': '11:30:00', 'JURIS_DESC': 'N.Y. POLICE DEPT', 'OFFENSE_CLASS_CODE': 233, 'LAW_CAT_CD': 'MISDEMEANOR', 'OFNS_DESC': 'SEX CRIMES', 'BORO_NM': 'QUEENS', 'PREM_TYP_DESC': 'PUBLIC SCHOOL', 'LOC_OF_OCCUR_DESC': 'INSIDE', 'SUSP_AGE_GROUP': '<18', 'SUSP_RACE': 'WHITE HISPANIC', 'SUSP_SEX': 'M', 'VIC_AGE_GROUP': '<18', 'VIC_RACE': 'WHITE HISPANIC', 'VIC_SEX': 'F'}
# {'_id': ObjectId('5fc69ff4d841acf8ef95b77d'), 'CMPLNT_NUM': 277618660, 'RPT_DT': '2020-06-28', 'CMPLNT_FR_DT': '2020-06-27', 'CMPLNT_TO_DT': '2020-06-27', 'CMPLNT_FR_TM': '00:00:00', 'CMPLNT_TO_TM': '01:30:00', 'JURIS_DESC': 'N.Y. POLICE DEPT', 'OFFENSE_CLASS_CODE': 578, 'LAW_CAT_CD': 'VIOLATION', 'OFNS_DESC': 'HARRASSMENT 2', 'BORO_NM': 'MANHATTAN', 'PREM_TYP_DESC': 'RESIDENCE - APT. HOUSE', 'LOC_OF_OCCUR_DESC': 'INSIDE', 'SUSP_AGE_GROUP': '45-64', 'SUSP_RACE': 'WHITE', 'SUSP_SEX': 'M', 'VIC_AGE_GROUP': '<18', 'VIC_RACE': 'ASIAN / PACIFIC ISLANDER', 'VIC_SEX': 'F'}
# {'_id': ObjectId('5fc69ff4d841acf8ef95b805'), 'CMPLNT_NUM': 159348585, 'RPT_DT': '2020-06-23', 'CMPLNT_FR_DT': '2020-06-23', 'CMPLNT_TO_DT': '2020-06-23', 'CMPLNT_FR_TM': '06:00:00', 'CMPLNT_TO_TM': '12:11:00', 'JURIS_DESC': 'N.Y. POLICE DEPT', 'OFFENSE_CLASS_CODE': 233, 'LAW_CAT_CD': 'MISDEMEANOR', 'OFNS_DESC': 'SEX CRIMES', 'BORO_NM': 'BRONX', 'PREM_TYP_DESC': 'RESIDENCE - APT. HOUSE', 'LOC_OF_OCCUR_DESC': 'INSIDE', 'SUSP_AGE_GROUP': '25-44', 'SUSP_RACE': 'WHITE HISPANIC', 'SUSP_SEX': 'F', 'VIC_AGE_GROUP': '<18', 'VIC_RACE': 'WHITE HISPANIC', 'VIC_SEX': 'F'}
# {'_id': ObjectId('5fc69ff4d841acf8ef95b820'), 'CMPLNT_NUM': 660624116, 'RPT_DT': '2020-06-24', 'CMPLNT_FR_DT': '2020-06-24', 'CMPLNT_TO_DT': '2020-06-24', 'CMPLNT_FR_TM': '15:15:00', 'CMPLNT_TO_TM': '15:30:00', 'JURIS_DESC': 'N.Y. POLICE DEPT', 'OFFENSE_CLASS_CODE': 344, 'LAW_CAT_CD': 'MISDEMEANOR', 'OFNS_DESC': 'ASSAULT 3 & RELATED OFFENSES', 'BORO_NM': 'STATEN ISLAND', 'PREM_TYP_DESC': 'RESIDENCE-HOUSE', 'LOC_OF_OCCUR_DESC': 'INSIDE', 'SUSP_AGE_GROUP': '25-44', 'SUSP_RACE': 'BLACK', 'SUSP_SEX': 'F', 'VIC_AGE_GROUP': '<18', 'VIC_RACE': 'BLACK', 'VIC_SEX': 'F'}
# {'_id': ObjectId('5fc69ff4d841acf8ef95b833'), 'CMPLNT_NUM': 549500915, 'RPT_DT': '2020-06-25', 'CMPLNT_FR_DT': '2020-06-25', 'CMPLNT_TO_DT': '2020-06-25', 'CMPLNT_FR_TM': '13:00:00', 'CMPLNT_TO_TM': '13:15:00', 'JURIS_DESC': 'N.Y. HOUSING POLICE', 'OFFENSE_CLASS_CODE': 359, 'LAW_CAT_CD': 'MISDEMEANOR', 'OFNS_DESC': 'OFFENSES AGAINST PUBLIC ADMINI', 'BORO_NM': 'MANHATTAN', 'PREM_TYP_DESC': 'RESIDENCE - PUBLIC HOUSING', 'LOC_OF_OCCUR_DESC': 'INSIDE', 'SUSP_AGE_GROUP': '18-24', 'SUSP_RACE': 'BLACK', 'SUSP_SEX': 'M', 'VIC_AGE_GROUP': '<18', 'VIC_RACE': 'BLACK', 'VIC_SEX': 'F'}
# {'_id': ObjectId('5fc69ff4d841acf8ef95b895'), 'CMPLNT_NUM': 494588723, 'RPT_DT': '2020-06-21', 'CMPLNT_FR_DT': '2020-06-21', 'CMPLNT_TO_DT': '2020-06-21', 'CMPLNT_FR_TM': '03:00:00', 'CMPLNT_TO_TM': '08:00:00', 'JURIS_DESC': 'N.Y. POLICE DEPT', 'OFFENSE_CLASS_CODE': 344, 'LAW_CAT_CD': 'MISDEMEANOR', 'OFNS_DESC': 'ASSAULT 3 & RELATED OFFENSES', 'BORO_NM': 'BRONX', 'PREM_TYP_DESC': 'RESIDENCE - APT. HOUSE', 'LOC_OF_OCCUR_DESC': 'INSIDE', 'SUSP_AGE_GROUP': '25-44', 'SUSP_RACE': 'BLACK HISPANIC', 'SUSP_SEX': 'M', 'VIC_AGE_GROUP': '<18', 'VIC_RACE': 'BLACK HISPANIC', 'VIC_SEX': 'F'}
# ...
# {'_id': ObjectId('5fc69ff7d841acf8ef97601f'), 'CMPLNT_NUM': 599970528, 'RPT_DT': '2020-02-01', 'CMPLNT_FR_DT': '2020-01-02', 'CMPLNT_TO_DT': '2020-02-01', 'CMPLNT_FR_TM': '20:15:00', 'CMPLNT_TO_TM': '20:30:00', 'JURIS_DESC': 'N.Y. POLICE DEPT', 'OFFENSE_CLASS_CODE': 233, 'LAW_CAT_CD': 'MISDEMEANOR', 'OFNS_DESC': 'SEX CRIMES', 'BORO_NM': 'QUEENS', 'PREM_TYP_DESC': 'RESIDENCE-HOUSE', 'LOC_OF_OCCUR_DESC': 'INSIDE', 'SUSP_AGE_GROUP': '25-44', 'SUSP_RACE': 'WHITE HISPANIC', 'SUSP_SEX': 'M', 'VIC_AGE_GROUP': '<18', 'VIC_RACE': 'WHITE HISPANIC', 'VIC_SEX': 'F'}
# {'_id': ObjectId('5fc69ff7d841acf8ef976074'), 'CMPLNT_NUM': 888522739, 'RPT_DT': '2020-04-01', 'CMPLNT_FR_DT': '2020-01-04', 'CMPLNT_TO_DT': '2020-04-01', 'CMPLNT_FR_TM': '08:23:00', 'CMPLNT_TO_TM': '08:25:00', 'JURIS_DESC': 'N.Y. POLICE DEPT', 'OFFENSE_CLASS_CODE': 126, 'LAW_CAT_CD': 'FELONY', 'OFNS_DESC': 'MISCELLANEOUS PENAL LAW', 'BORO_NM': 'BROOKLYN', 'PREM_TYP_DESC': 'RESIDENCE - APT. HOUSE', 'LOC_OF_OCCUR_DESC': 'INSIDE', 'SUSP_AGE_GROUP': '25-44', 'SUSP_RACE': 'BLACK HISPANIC', 'SUSP_SEX': 'M', 'VIC_AGE_GROUP': '<18', 'VIC_RACE': 'WHITE HISPANIC', 'VIC_SEX': 'F'}
# {'_id': ObjectId('5fc69ff7d841acf8ef9760ab'), 'CMPLNT_NUM': 647306199, 'RPT_DT': '2020-03-01', 'CMPLNT_FR_DT': '2019-12-26', 'CMPLNT_TO_DT': '2019-12-27', 'CMPLNT_FR_TM': '19:07:00', 'CMPLNT_TO_TM': '00:00:00', 'JURIS_DESC': 'N.Y. POLICE DEPT', 'OFFENSE_CLASS_CODE': 361, 'LAW_CAT_CD': 'MISDEMEANOR', 'OFNS_DESC': 'OFF. AGNST PUB ORD SENSBLTY &', 'BORO_NM': 'BRONX', 'PREM_TYP_DESC': 'RESIDENCE - APT. HOUSE', 'LOC_OF_OCCUR_DESC': 'INSIDE', 'SUSP_AGE_GROUP': '<18', 'SUSP_RACE': 'BLACK', 'SUSP_SEX': 'M', 'VIC_AGE_GROUP': '<18', 'VIC_RACE': 'BLACK', 'VIC_SEX': 'F'}
# {'_id': ObjectId('5fc69ff7d841acf8ef9760e0'), 'CMPLNT_NUM': 178517709, 'RPT_DT': '2020-01-01', 'CMPLNT_FR_DT': '2019-12-19', 'CMPLNT_TO_DT': '2019-12-19', 'CMPLNT_FR_TM': '22:00:00', 'CMPLNT_TO_TM': '22:00:00', 'JURIS_DESC': 'N.Y. POLICE DEPT', 'OFFENSE_CLASS_CODE': 106, 'LAW_CAT_CD': 'FELONY', 'OFNS_DESC': 'FELONY ASSAULT', 'BORO_NM': 'QUEENS', 'PREM_TYP_DESC': 'STREET', 'LOC_OF_OCCUR_DESC': 'FRONT OF', 'SUSP_AGE_GROUP': '18-24', 'SUSP_RACE': 'ASIAN / PACIFIC ISLANDER', 'SUSP_SEX': 'M', 'VIC_AGE_GROUP': '<18', 'VIC_RACE': 'ASIAN / PACIFIC ISLANDER', 'VIC_SEX': 'F'}
# {'_id': ObjectId('5fc69ff7d841acf8ef9760ec'), 'CMPLNT_NUM': 520364025, 'RPT_DT': '2020-02-01', 'CMPLNT_FR_DT': '2020-01-02', 'CMPLNT_TO_DT': '2020-02-01', 'CMPLNT_FR_TM': '14:40:00', 'CMPLNT_TO_TM': '14:40:00', 'JURIS_DESC': 'N.Y. POLICE DEPT', 'OFFENSE_CLASS_CODE': 109, 'LAW_CAT_CD': 'FELONY', 'OFNS_DESC': 'GRAND LARCENY', 'BORO_NM': 'QUEENS', 'PREM_TYP_DESC': 'STREET', 'LOC_OF_OCCUR_DESC': 'FRONT OF', 'SUSP_AGE_GROUP': 'UNKNOWN', 'SUSP_RACE': 'UNKNOWN', 'SUSP_SEX': 'M', 'VIC_AGE_GROUP': '<18', 'VIC_RACE': 'ASIAN / PACIFIC ISLANDER', 'VIC_SEX': 'F'}
# {'_id': ObjectId('5fc69ff7d841acf8ef97613a'), 'CMPLNT_NUM': 900180387, 'RPT_DT': '2020-01-01', 'CMPLNT_FR_DT': '2020-01-01', 'CMPLNT_TO_DT': '2020-01-01', 'CMPLNT_FR_TM': '17:30:00', 'CMPLNT_TO_TM': '17:50:00', 'JURIS_DESC': 'N.Y. POLICE DEPT', 'OFFENSE_CLASS_CODE': 578, 'LAW_CAT_CD': 'VIOLATION', 'OFNS_DESC': 'HARRASSMENT 2', 'BORO_NM': 'QUEENS', 'PREM_TYP_DESC': 'RESIDENCE-HOUSE', 'LOC_OF_OCCUR_DESC': 'INSIDE', 'SUSP_AGE_GROUP': '45-64', 'SUSP_RACE': 'ASIAN / PACIFIC ISLANDER', 'SUSP_SEX': 'F', 'VIC_AGE_GROUP': '<18', 'VIC_RACE': 'ASIAN / PACIFIC ISLANDER', 'VIC_SEX': 'F'}
# {'_id': ObjectId('5fc69ff7d841acf8ef9761c5'), 'CMPLNT_NUM': 122934103, 'RPT_DT': '2020-02-01', 'CMPLNT_FR_DT': '2019-08-08', 'CMPLNT_TO_DT': '2020-02-01', 'CMPLNT_FR_TM': '11:00:00', 'CMPLNT_TO_TM': '16:30:00', 'JURIS_DESC': 'N.Y. POLICE DEPT', 'OFFENSE_CLASS_CODE': 361, 'LAW_CAT_CD': 'MISDEMEANOR', 'OFNS_DESC': 'OFF. AGNST PUB ORD SENSBLTY &', 'BORO_NM': 'MANHATTAN', 'PREM_TYP_DESC': 'STREET', 'LOC_OF_OCCUR_DESC': 'FRONT OF', 'SUSP_AGE_GROUP': '<18', 'SUSP_RACE': 'WHITE HISPANIC', 'SUSP_SEX': 'F', 'VIC_AGE_GROUP': '<18', 'VIC_RACE': 'WHITE HISPANIC', 'VIC_SEX': 'F'}
# {'_id': ObjectId('5fc69ff7d841acf8ef9761e4'), 'CMPLNT_NUM': 443535586, 'RPT_DT': '2020-02-01', 'CMPLNT_FR_DT': '2020-01-02', 'CMPLNT_TO_DT': '2020-02-01', 'CMPLNT_FR_TM': '13:43:00', 'CMPLNT_TO_TM': '13:50:00', 'JURIS_DESC': 'N.Y. POLICE DEPT', 'OFFENSE_CLASS_CODE': 116, 'LAW_CAT_CD': 'FELONY', 'OFNS_DESC': 'SEX CRIMES', 'BORO_NM': 'BRONX', 'PREM_TYP_DESC': 'RESIDENCE - APT. HOUSE', 'LOC_OF_OCCUR_DESC': 'INSIDE', 'SUSP_AGE_GROUP': '25-44', 'SUSP_RACE': 'BLACK', 'SUSP_SEX': 'M', 'VIC_AGE_GROUP': '<18', 'VIC_RACE': 'BLACK', 'VIC_SEX': 'F'}
# {'_id': ObjectId('5fc69ff7d841acf8ef9761ea'), 'CMPLNT_NUM': 554182171, 'RPT_DT': '2020-01-01', 'CMPLNT_FR_DT': '2019-08-15', 'CMPLNT_TO_DT': '2019-08-15', 'CMPLNT_FR_TM': '10:00:00', 'CMPLNT_TO_TM': '10:20:00', 'JURIS_DESC': 'N.Y. POLICE DEPT', 'OFFENSE_CLASS_CODE': 104, 'LAW_CAT_CD': 'FELONY', 'OFNS_DESC': 'RAPE', 'BORO_NM': 'BRONX', 'PREM_TYP_DESC': 'RESIDENCE - APT. HOUSE', 'LOC_OF_OCCUR_DESC': 'INSIDE', 'SUSP_AGE_GROUP': '25-44', 'SUSP_RACE': 'UNKNOWN', 'SUSP_SEX': 'M', 'VIC_AGE_GROUP': '<18', 'VIC_RACE': 'BLACK', 'VIC_SEX': 'F'}
# {'_id': ObjectId('5fc69ff7d841acf8ef976234'), 'CMPLNT_NUM': 590446701, 'RPT_DT': '2020-02-01', 'CMPLNT_FR_DT': '2020-01-02', 'CMPLNT_TO_DT': '2020-02-01', 'CMPLNT_FR_TM': '09:50:00', 'CMPLNT_TO_TM': '10:00:00', 'JURIS_DESC': 'N.Y. POLICE DEPT', 'OFFENSE_CLASS_CODE': 344, 'LAW_CAT_CD': 'MISDEMEANOR', 'OFNS_DESC': 'ASSAULT 3 & RELATED OFFENSES', 'BORO_NM': 'MANHATTAN', 'PREM_TYP_DESC': 'PUBLIC SCHOOL', 'LOC_OF_OCCUR_DESC': 'INSIDE', 'SUSP_AGE_GROUP': '18-24', 'SUSP_RACE': 'BLACK', 'SUSP_SEX': 'U', 'VIC_AGE_GROUP': '<18', 'VIC_RACE': 'UNKNOWN', 'VIC_SEX': 'F'}
# {'_id': ObjectId('5fc69ff7d841acf8ef976242'), 'CMPLNT_NUM': 906816586, 'RPT_DT': '2020-04-01', 'CMPLNT_FR_DT': '2009-07-08', 'CMPLNT_TO_DT': '2013-08-07', 'CMPLNT_FR_TM': '20:00:00', 'CMPLNT_TO_TM': '20:00:00', 'JURIS_DESC': 'N.Y. HOUSING POLICE', 'OFFENSE_CLASS_CODE': 116, 'LAW_CAT_CD': 'FELONY', 'OFNS_DESC': 'SEX CRIMES', 'BORO_NM': 'STATEN ISLAND', 'PREM_TYP_DESC': 'RESIDENCE - PUBLIC HOUSING', 'LOC_OF_OCCUR_DESC': 'INSIDE', 'SUSP_AGE_GROUP': '18-24', 'SUSP_RACE': 'BLACK', 'SUSP_SEX': 'M', 'VIC_AGE_GROUP': '<18', 'VIC_RACE': 'BLACK HISPANIC', 'VIC_SEX': 'F'}
# {'_id': ObjectId('5fc69ff7d841acf8ef976257'), 'CMPLNT_NUM': 687118099, 'RPT_DT': '2020-04-01', 'CMPLNT_FR_DT': '2020-01-04', 'CMPLNT_TO_DT': '2020-04-01', 'CMPLNT_FR_TM': '17:00:00', 'CMPLNT_TO_TM': '17:15:00', 'JURIS_DESC': 'N.Y. POLICE DEPT', 'OFFENSE_CLASS_CODE': 344, 'LAW_CAT_CD': 'MISDEMEANOR', 'OFNS_DESC': 'ASSAULT 3 & RELATED OFFENSES', 'BORO_NM': 'QUEENS', 'PREM_TYP_DESC': 'STREET', 'LOC_OF_OCCUR_DESC': 'FRONT OF', 'SUSP_AGE_GROUP': 'UNKNOWN', 'SUSP_RACE': 'UNKNOWN', 'SUSP_SEX': 'U', 'VIC_AGE_GROUP': '<18', 'VIC_RACE': 'BLACK', 'VIC_SEX': 'F'}
# {'_id': ObjectId('5fc69ff7d841acf8ef976260'), 'CMPLNT_NUM': 624126617, 'RPT_DT': '2020-03-01', 'CMPLNT_FR_DT': '2020-01-03', 'CMPLNT_TO_DT': '2020-03-01', 'CMPLNT_FR_TM': '15:35:00', 'CMPLNT_TO_TM': '15:45:00', 'JURIS_DESC': 'N.Y. POLICE DEPT', 'OFFENSE_CLASS_CODE': 105, 'LAW_CAT_CD': 'FELONY', 'OFNS_DESC': 'ROBBERY', 'BORO_NM': 'BRONX', 'PREM_TYP_DESC': 'RESIDENCE - APT. HOUSE', 'LOC_OF_OCCUR_DESC': 'INSIDE', 'SUSP_AGE_GROUP': '<18', 'SUSP_RACE': 'WHITE HISPANIC', 'SUSP_SEX': 'M', 'VIC_AGE_GROUP': '<18', 'VIC_RACE': 'UNKNOWN', 'VIC_SEX': 'F'}
# {'_id': ObjectId('5fc69ff7d841acf8ef976265'), 'CMPLNT_NUM': 810201242, 'RPT_DT': '2020-03-01', 'CMPLNT_FR_DT': '2019-11-03', 'CMPLNT_TO_DT': '2019-03-11', 'CMPLNT_FR_TM': '00:01:00', 'CMPLNT_TO_TM': '23:59:00', 'JURIS_DESC': 'N.Y. POLICE DEPT', 'OFFENSE_CLASS_CODE': 233, 'LAW_CAT_CD': 'MISDEMEANOR', 'OFNS_DESC': 'SEX CRIMES', 'BORO_NM': 'QUEENS', 'PREM_TYP_DESC': 'RESIDENCE-HOUSE', 'LOC_OF_OCCUR_DESC': 'INSIDE', 'SUSP_AGE_GROUP': '18-24', 'SUSP_RACE': 'WHITE HISPANIC', 'SUSP_SEX': 'M', 'VIC_AGE_GROUP': '<18', 'VIC_RACE': 'BLACK HISPANIC', 'VIC_SEX': 'F'}
# {'_id': ObjectId('5fc69ff7d841acf8ef9762b1'), 'CMPLNT_NUM': 741983480, 'RPT_DT': '2020-03-01', 'CMPLNT_FR_DT': '2019-12-20', 'CMPLNT_TO_DT': '2019-12-20', 'CMPLNT_FR_TM': '12:00:00', 'CMPLNT_TO_TM': '12:05:00', 'JURIS_DESC': 'N.Y. POLICE DEPT', 'OFFENSE_CLASS_CODE': 233, 'LAW_CAT_CD': 'MISDEMEANOR', 'OFNS_DESC': 'SEX CRIMES', 'BORO_NM': 'QUEENS', 'PREM_TYP_DESC': 'HOTEL/MOTEL', 'LOC_OF_OCCUR_DESC': 'INSIDE', 'SUSP_AGE_GROUP': '18-24', 'SUSP_RACE': 'BLACK', 'SUSP_SEX': 'M', 'VIC_AGE_GROUP': '<18', 'VIC_RACE': 'BLACK', 'VIC_SEX': 'F'}
# {'_id': ObjectId('5fc69ff7d841acf8ef9762c9'), 'CMPLNT_NUM': 402684606, 'RPT_DT': '2020-02-01', 'CMPLNT_FR_DT': '2020-01-02', 'CMPLNT_TO_DT': '2020-02-01', 'CMPLNT_FR_TM': '09:00:00', 'CMPLNT_TO_TM': '09:15:00', 'JURIS_DESC': 'N.Y. POLICE DEPT', 'OFFENSE_CLASS_CODE': 361, 'LAW_CAT_CD': 'MISDEMEANOR', 'OFNS_DESC': 'OFF. AGNST PUB ORD SENSBLTY &', 'BORO_NM': 'BRONX', 'PREM_TYP_DESC': 'STREET', 'LOC_OF_OCCUR_DESC': 'FRONT OF', 'SUSP_AGE_GROUP': '25-44', 'SUSP_RACE': 'BLACK', 'SUSP_SEX': 'M', 'VIC_AGE_GROUP': '<18', 'VIC_RACE': 'WHITE HISPANIC', 'VIC_SEX': 'F'}
# {'_id': ObjectId('5fc69ff7d841acf8ef9762df'), 'CMPLNT_NUM': 609635208, 'RPT_DT': '2020-03-01', 'CMPLNT_FR_DT': '2019-12-10', 'CMPLNT_TO_DT': '2019-10-12', 'CMPLNT_FR_TM': '12:35:00', 'CMPLNT_TO_TM': '12:50:00', 'JURIS_DESC': 'N.Y. POLICE DEPT', 'OFFENSE_CLASS_CODE': 344, 'LAW_CAT_CD': 'MISDEMEANOR', 'OFNS_DESC': 'ASSAULT 3 & RELATED OFFENSES', 'BORO_NM': 'BRONX', 'PREM_TYP_DESC': 'PRIVATE/PAROCHIAL SCHOOL', 'LOC_OF_OCCUR_DESC': 'INSIDE', 'SUSP_AGE_GROUP': '18-24', 'SUSP_RACE': 'BLACK', 'SUSP_SEX': 'F', 'VIC_AGE_GROUP': '<18', 'VIC_RACE': 'WHITE HISPANIC', 'VIC_SEX': 'F'}
# {'_id': ObjectId('5fc69ff7d841acf8ef97633e'), 'CMPLNT_NUM': 103175582, 'RPT_DT': '2020-02-01', 'CMPLNT_FR_DT': '2019-12-26', 'CMPLNT_TO_DT': '2020-02-01', 'CMPLNT_FR_TM': '15:00:00', 'CMPLNT_TO_TM': '11:00:00', 'JURIS_DESC': 'N.Y. POLICE DEPT', 'OFFENSE_CLASS_CODE': 361, 'LAW_CAT_CD': 'MISDEMEANOR', 'OFNS_DESC': 'OFF. AGNST PUB ORD SENSBLTY &', 'BORO_NM': 'MANHATTAN', 'PREM_TYP_DESC': 'PUBLIC SCHOOL', 'LOC_OF_OCCUR_DESC': 'INSIDE', 'SUSP_AGE_GROUP': 'UNKNOWN', 'SUSP_RACE': 'UNKNOWN', 'SUSP_SEX': 'U', 'VIC_AGE_GROUP': '<18', 'VIC_RACE': 'WHITE', 'VIC_SEX': 'F'}
# {'_id': ObjectId('5fc69ff7d841acf8ef976368'), 'CMPLNT_NUM': 148576476, 'RPT_DT': '2020-04-01', 'CMPLNT_FR_DT': '2020-01-04', 'CMPLNT_TO_DT': '2020-04-01', 'CMPLNT_FR_TM': '13:51:00', 'CMPLNT_TO_TM': '14:10:00', 'JURIS_DESC': 'N.Y. POLICE DEPT', 'OFFENSE_CLASS_CODE': 106, 'LAW_CAT_CD': 'FELONY', 'OFNS_DESC': 'FELONY ASSAULT', 'BORO_NM': 'MANHATTAN', 'PREM_TYP_DESC': 'RESIDENCE - APT. HOUSE', 'LOC_OF_OCCUR_DESC': 'INSIDE', 'SUSP_AGE_GROUP': '25-44', 'SUSP_RACE': 'BLACK', 'SUSP_SEX': 'F', 'VIC_AGE_GROUP': '<18', 'VIC_RACE': 'BLACK', 'VIC_SEX': 'F'}
# {'_id': ObjectId('5fc69ff7d841acf8ef97636c'), 'CMPLNT_NUM': 619811550, 'RPT_DT': '2020-03-01', 'CMPLNT_FR_DT': '2019-12-01', 'CMPLNT_TO_DT': '2019-12-31', 'CMPLNT_FR_TM': '00:00:00', 'CMPLNT_TO_TM': '23:59:00', 'JURIS_DESC': 'N.Y. POLICE DEPT', 'OFFENSE_CLASS_CODE': 578, 'LAW_CAT_CD': 'VIOLATION', 'OFNS_DESC': 'HARRASSMENT 2', 'BORO_NM': 'STATEN ISLAND', 'PREM_TYP_DESC': 'RESIDENCE-HOUSE', 'LOC_OF_OCCUR_DESC': 'INSIDE', 'SUSP_AGE_GROUP': '45-64', 'SUSP_RACE': 'WHITE', 'SUSP_SEX': 'M', 'VIC_AGE_GROUP': '<18', 'VIC_RACE': 'WHITE', 'VIC_SEX': 'F'}
# {'_id': ObjectId('5fc69ff7d841acf8ef97638b'), 'CMPLNT_NUM': 136804458, 'RPT_DT': '2020-03-01', 'CMPLNT_FR_DT': '2020-01-03', 'CMPLNT_TO_DT': '2020-03-01', 'CMPLNT_FR_TM': '17:46:00', 'CMPLNT_TO_TM': '18:00:00', 'JURIS_DESC': 'N.Y. HOUSING POLICE', 'OFFENSE_CLASS_CODE': 578, 'LAW_CAT_CD': 'VIOLATION', 'OFNS_DESC': 'HARRASSMENT 2', 'BORO_NM': 'MANHATTAN', 'PREM_TYP_DESC': 'RESIDENCE - PUBLIC HOUSING', 'LOC_OF_OCCUR_DESC': 'INSIDE', 'SUSP_AGE_GROUP': 'UNKNOWN', 'SUSP_RACE': 'BLACK', 'SUSP_SEX': 'F', 'VIC_AGE_GROUP': '<18', 'VIC_RACE': 'UNKNOWN', 'VIC_SEX': 'F'}
# {'_id': ObjectId('5fc69ff7d841acf8ef976390'), 'CMPLNT_NUM': 622711957, 'RPT_DT': '2020-02-01', 'CMPLNT_FR_DT': '2020-01-02', 'CMPLNT_TO_DT': '2020-02-01', 'CMPLNT_FR_TM': '07:30:00', 'CMPLNT_TO_TM': '16:10:00', 'JURIS_DESC': 'N.Y. POLICE DEPT', 'OFFENSE_CLASS_CODE': 344, 'LAW_CAT_CD': 'MISDEMEANOR', 'OFNS_DESC': 'ASSAULT 3 & RELATED OFFENSES', 'BORO_NM': 'STATEN ISLAND', 'PREM_TYP_DESC': 'PUBLIC SCHOOL', 'LOC_OF_OCCUR_DESC': 'REAR OF', 'SUSP_AGE_GROUP': 'UNKNOWN', 'SUSP_RACE': 'UNKNOWN', 'SUSP_SEX': 'U', 'VIC_AGE_GROUP': '<18', 'VIC_RACE': 'UNKNOWN', 'VIC_SEX': 'F'}
# {'_id': ObjectId('5fc69ff7d841acf8ef9763a1'), 'CMPLNT_NUM': 890800343, 'RPT_DT': '2020-04-01', 'CMPLNT_FR_DT': '2020-01-04', 'CMPLNT_TO_DT': '2020-04-01', 'CMPLNT_FR_TM': '01:40:00', 'CMPLNT_TO_TM': '02:00:00', 'JURIS_DESC': 'N.Y. POLICE DEPT', 'OFFENSE_CLASS_CODE': 344, 'LAW_CAT_CD': 'MISDEMEANOR', 'OFNS_DESC': 'ASSAULT 3 & RELATED OFFENSES', 'BORO_NM': 'QUEENS', 'PREM_TYP_DESC': 'RESIDENCE - APT. HOUSE', 'LOC_OF_OCCUR_DESC': 'INSIDE', 'SUSP_AGE_GROUP': '25-44', 'SUSP_RACE': 'BLACK HISPANIC', 'SUSP_SEX': 'M', 'VIC_AGE_GROUP': '<18', 'VIC_RACE': 'BLACK HISPANIC', 'VIC_SEX': 'F'}
# {'_id': ObjectId('5fc69ff7d841acf8ef9763b1'), 'CMPLNT_NUM': 193244027, 'RPT_DT': '2020-03-01', 'CMPLNT_FR_DT': '2020-01-02', 'CMPLNT_TO_DT': '2020-02-01', 'CMPLNT_FR_TM': '12:45:00', 'CMPLNT_TO_TM': '12:45:00', 'JURIS_DESC': 'N.Y. POLICE DEPT', 'OFFENSE_CLASS_CODE': 233, 'LAW_CAT_CD': 'MISDEMEANOR', 'OFNS_DESC': 'SEX CRIMES', 'BORO_NM': 'BRONX', 'PREM_TYP_DESC': 'PUBLIC SCHOOL', 'LOC_OF_OCCUR_DESC': 'INSIDE', 'SUSP_AGE_GROUP': '<18', 'SUSP_RACE': 'BLACK', 'SUSP_SEX': 'M', 'VIC_AGE_GROUP': '<18', 'VIC_RACE': 'WHITE HISPANIC', 'VIC_SEX': 'F'}
# {'_id': ObjectId('5fc69ff7d841acf8ef9763fc'), 'CMPLNT_NUM': 331017091, 'RPT_DT': '2020-01-01', 'CMPLNT_FR_DT': '2019-12-31', 'CMPLNT_TO_DT': '2019-12-31', 'CMPLNT_FR_TM': '22:00:00', 'CMPLNT_TO_TM': '22:30:00', 'JURIS_DESC': 'N.Y. POLICE DEPT', 'OFFENSE_CLASS_CODE': 578, 'LAW_CAT_CD': 'VIOLATION', 'OFNS_DESC': 'HARRASSMENT 2', 'BORO_NM': 'STATEN ISLAND', 'PREM_TYP_DESC': 'RESIDENCE-HOUSE', 'LOC_OF_OCCUR_DESC': 'INSIDE', 'SUSP_AGE_GROUP': '<18', 'SUSP_RACE': 'BLACK', 'SUSP_SEX': 'F', 'VIC_AGE_GROUP': '<18', 'VIC_RACE': 'BLACK', 'VIC_SEX': 'F'}
# {'_id': ObjectId('5fc69ff7d841acf8ef9763fe'), 'CMPLNT_NUM': 859089350, 'RPT_DT': '2020-02-01', 'CMPLNT_FR_DT': '2019-12-23', 'CMPLNT_TO_DT': '2020-02-01', 'CMPLNT_FR_TM': '07:00:00', 'CMPLNT_TO_TM': '11:30:00', 'JURIS_DESC': 'N.Y. POLICE DEPT', 'OFFENSE_CLASS_CODE': 578, 'LAW_CAT_CD': 'VIOLATION', 'OFNS_DESC': 'HARRASSMENT 2', 'BORO_NM': 'STATEN ISLAND', 'PREM_TYP_DESC': 'PUBLIC SCHOOL', 'LOC_OF_OCCUR_DESC': 'INSIDE', 'SUSP_AGE_GROUP': '<18', 'SUSP_RACE': 'WHITE', 'SUSP_SEX': 'F', 'VIC_AGE_GROUP': '<18', 'VIC_RACE': 'WHITE', 'VIC_SEX': 'F'}
# {'_id': ObjectId('5fc69ff7d841acf8ef976432'), 'CMPLNT_NUM': 905957329, 'RPT_DT': '2020-03-01', 'CMPLNT_FR_DT': '2019-12-28', 'CMPLNT_TO_DT': '2019-12-28', 'CMPLNT_FR_TM': '07:00:00', 'CMPLNT_TO_TM': '08:00:00', 'JURIS_DESC': 'N.Y. POLICE DEPT', 'OFFENSE_CLASS_CODE': 116, 'LAW_CAT_CD': 'FELONY', 'OFNS_DESC': 'SEX CRIMES', 'BORO_NM': 'BROOKLYN', 'PREM_TYP_DESC': 'RESIDENCE - APT. HOUSE', 'LOC_OF_OCCUR_DESC': 'INSIDE', 'SUSP_AGE_GROUP': '25-44', 'SUSP_RACE': 'BLACK', 'SUSP_SEX': 'M', 'VIC_AGE_GROUP': '<18', 'VIC_RACE': 'BLACK', 'VIC_SEX': 'F'}
# {'_id': ObjectId('5fc69ff7d841acf8ef97644a'), 'CMPLNT_NUM': 866058828, 'RPT_DT': '2020-02-01', 'CMPLNT_FR_DT': '2020-01-02', 'CMPLNT_TO_DT': '2020-02-01', 'CMPLNT_FR_TM': '11:12:00', 'CMPLNT_TO_TM': '11:15:00', 'JURIS_DESC': 'N.Y. POLICE DEPT', 'OFFENSE_CLASS_CODE': 344, 'LAW_CAT_CD': 'MISDEMEANOR', 'OFNS_DESC': 'ASSAULT 3 & RELATED OFFENSES', 'BORO_NM': 'QUEENS', 'PREM_TYP_DESC': 'COMMERCIAL BUILDING', 'LOC_OF_OCCUR_DESC': 'INSIDE', 'SUSP_AGE_GROUP': '45-64', 'SUSP_RACE': 'BLACK', 'SUSP_SEX': 'F', 'VIC_AGE_GROUP': '<18', 'VIC_RACE': 'WHITE HISPANIC', 'VIC_SEX': 'F'}

# %%
# Query 7: Find all possible type of Felonies
for x in mycol.find({ "LAW_CAT_CD" :'FELONY'}).distinct('OFNS_DESC'):
    print(x)
# Out:
# ARSON
# BURGLARY
# CHILD ABANDONMENT/NON SUPPORT
# CRIMINAL MISCHIEF & RELATED OF
# DANGEROUS DRUGS
# DANGEROUS WEAPONS
# ENDAN WELFARE INCOMP
# FELONY ASSAULT
# FELONY SEX CRIMES
# FORGERY
# GAMBLING
# GRAND LARCENY
# GRAND LARCENY OF MOTOR VEHICLE
# HOMICIDE-NEGLIGENT,UNCLASSIFIE
# KIDNAPPING & RELATED OFFENSES
# MISCELLANEOUS PENAL LAW
# NYS LAWS-UNCLASSIFIED FELONY
# OTHER STATE LAWS (NON PENAL LA
# POSSESSION OF STOLEN PROPERTY
# RAPE
# ROBBERY
# SEX CRIMES
# THEFT-FRAUD

# %%
# Query 8: Find number of crimes in each borough
result = mycol.aggregate([
    # Group the documents and "count" via $sum on the values
    { "$group": {
        "_id": {
            "Borough": "$BORO_NM"
        },
        "#Crimes": { "$sum": 1 }
    }},
    
    #Sort results by #Crimes
    { "$sort": { "#Crimes": -1 } }
])
for x in result:
    print(x)
# Out:
# {'_id': {'Borough': 'BROOKLYN'}, '#Crimes': 33541}
# {'_id': {'Borough': 'MANHATTAN'}, '#Crimes': 28704}
# {'_id': {'Borough': 'QUEENS'}, '#Crimes': 25018}
# {'_id': {'Borough': 'BRONX'}, '#Crimes': 22932}
# {'_id': {'Borough': 'STATEN ISLAND'}, '#Crimes': 4422}

# %%
def make_json(csvFilePath, jsonFilePath): 
      
    # create a dictionary 
    data = {} 
      
    # Open a csv reader called DictReader 
    with open(csvFilePath, encoding='utf-8') as csvf: 
        csvReader = csv.DictReader(csvf) 
          
        # Convert each row into a dictionary  
        # and add it to data 
        for rows in csvReader: 
              
            # Assuming a column named 'No' to 
            # be the primary key 
            key = rows['CMPLNT_NUM'] 
            data[key] = rows 
  
    # Open a json writer, and use the json.dumps()  
    # function to dump data 
    with open(jsonFilePath, 'w', encoding='utf-8') as jsonf: 
        jsonf.write(json.dumps(data, indent=4))

# %%
csvFilePath = r'bogus_complete.csv'
jsonFilePath = r'bogus_complete.json'

# %%
make_json(csvFilePath, jsonFilePath)

# %%
with open(jsonFilePath) as f:
    file_data = json.load(f)

# %%
type(file_data)
# Out:
# dict

# %%
mycol.insert_many(file_data)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-94-2034536bf598> in <module>
# ----> 1 mycol.insert_many(file_data)
#
# ~/anaconda3/lib/python3.7/site-packages/pymongo/collection.py in insert_many(self, documents, ordered, bypass_document_validation, session)
#     758         write_concern = self._write_concern_for(session)
#     759         blk = _Bulk(self, ordered, bypass_document_validation)
# --> 760         blk.ops = [doc for doc in gen()]
#     761         blk.execute(write_concern, session=session)
#     762         return InsertManyResult(inserted_ids, write_concern.acknowledged)
#
# ~/anaconda3/lib/python3.7/site-packages/pymongo/collection.py in <listcomp>(.0)
#     758         write_concern = self._write_concern_for(session)
#     759         blk = _Bulk(self, ordered, bypass_document_validation)
# --> 760         blk.ops = [doc for doc in gen()]
#     761         blk.execute(write_concern, session=session)
#     762         return InsertManyResult(inserted_ids, write_concern.acknowledged)
#
# ~/anaconda3/lib/python3.7/site-packages/pymongo/collection.py in gen()
#     749             """A generator that validates documents and handles _ids."""
#     750             for document in documents:
# --> 751                 common.validate_is_document_type("document", document)
#     752                 if not isinstance(document, RawBSONDocument):
#     753                     if "_id" not in document:
#
# ~/anaconda3/lib/python3.7/site-packages/pymongo/common.py in validate_is_document_type(option, value)
#     503                         "bson.raw_bson.RawBSONDocument, or "
#     504                         "a type that inherits from "
# --> 505                         "collections.MutableMapping" % (option,))
#     506
#     507
#
# TypeError: document must be an instance of dict, bson.son.SON, bson.raw_bson.RawBSONDocument, or a type that inherits from collections.MutableMapping

# %%
type(mycol)
# Out:
# pymongo.collection.Collection
